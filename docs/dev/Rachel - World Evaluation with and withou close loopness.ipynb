# %% [markdown]
# # Rachel - World Evluation with and without close loopness
#
# Base scenario: 75 TW deployment, End of Life linear (all waste, no recycling)
# Comparison scenario: including recycling and close-loop values from Rachel's paper. Pointing to a database folder generated with these values.

# %% [markdown]
# ## 1. Setup and Create PV ICE Simulation Object

# %%
import PV_ICE
import os,sys
from pathlib import Path
import matplotlib.pyplot as plt
import pandas as pd
PV_ICE.__version__
# Out:
# 'v0.2.0+661.gda724de.dirty'

# %%
# This information helps with debugging and getting support :)
import sys, platform
print("Working on a ", platform.system(), platform.release())
print("Python version ", sys.version)
print("Pandas version ", pd.__version__)
print("PV_ICE version ", PV_ICE.__version__)
# Out:
# Working on a  Windows 11
# Python version  3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 13:17:27) [MSC v.1929 64 bit (AMD64)]
# Pandas version  2.2.2
# PV_ICE version  v0.2.0+661.gda724de.dirty

# %%
testfolder = str(Path().resolve().parent.parent / 'PV_ICE' / 'TEMP' / 'Rachel')
baselinesfolder = str(Path().resolve().parent.parent /'PV_ICE' / 'baselines')
rachaelbaselinesfolder = str(Path().resolve().parent.parent /'PV_ICE' / 'baselines' / 'WR_baselines' )

if not os.path.exists(testfolder):
    os.makedirs(testfolder)

# %%
r1 = PV_ICE.Simulation(name='Sim', path=testfolder, baselinepath=baselinesfolder); # Is it possible to define more than one simulation here?
# Out:
# path = C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\TEMP\Rachel
# Making path: raw
# Making path: input
# Making path: output
# Making path: figures

# %% [markdown]
# ## 3. Create standard and modified scenarios

# %%
r1.createScenario(name='standard_SHJ', 
                  massmodulefile=r'baseline_modules_mass_World_SHJ.csv', 
                  energymodulefile = 'baseline_modules_energy.csv' )

r1.scenario['standard_SHJ'].addMaterial(materialname='glass', 
                                    massmatfile=os.path.join(baselinesfolder, 'baseline_material_mass_glass.csv'),
                                    energymatfile=os.path.join(baselinesfolder, 'baseline_material_energy_glass.csv'))

r1.scenario['standard_SHJ'].addMaterial(materialname='silicon', 
                                    massmatfile=os.path.join(baselinesfolder, 'baseline_material_mass_silicon.csv'),
                                    energymatfile=os.path.join(baselinesfolder, 'baseline_material_energy_silicon.csv'))

r1.scenario['standard_SHJ'].addMaterial(materialname='copper', 
                                    massmatfile=os.path.join(baselinesfolder, 'baseline_material_mass_copper.csv'),
                                    energymatfile=os.path.join(baselinesfolder, 'baseline_material_energy_copper.csv'))

r1.scenario['standard_SHJ'].addMaterial(materialname='silver', 
                                    massmatfile=os.path.join(baselinesfolder, 'baseline_material_mass_silver.csv'),
                                    energymatfile=os.path.join(baselinesfolder, 'baseline_material_energy_silver.csv'))
r1.scenario['standard_SHJ'].addMaterial(materialname='aluminium_frames', 
                                    massmatfile=os.path.join(baselinesfolder, 'baseline_material_mass_aluminium_frames.csv'),
                                    energymatfile=os.path.join(baselinesfolder, 'baseline_material_energy_aluminium_frames.csv'))

r1.scenario['standard_SHJ'].addMaterial(materialname='encapsulant', 
                                    massmatfile=os.path.join(baselinesfolder, 'baseline_material_mass_encapsulant.csv'),
                                    energymatfile=os.path.join(baselinesfolder, 'baseline_material_energy_encapsulant.csv'))

r1.scenario['standard_SHJ'].addMaterial(materialname='backsheet', 
                                    massmatfile=os.path.join(baselinesfolder, 'baseline_material_mass_backsheet.csv'),
                                    energymatfile=os.path.join(baselinesfolder, 'baseline_material_energy_backsheet.csv'))

# %%
r1.createScenario(name='standard_TopCon', 
                  massmodulefile=r'baseline_modules_mass_World_SHJ.csv', 
                  energymodulefile = 'baseline_modules_energy.csv' )

r1.scenario['standard_TopCon'].addMaterial(materialname='glass', 
                                    massmatfile=os.path.join(baselinesfolder, 'baseline_material_mass_glass.csv'),
                                    energymatfile=os.path.join(baselinesfolder, 'baseline_material_energy_glass.csv'))

r1.scenario['standard_TopCon'].addMaterial(materialname='silicon', 
                                    massmatfile=os.path.join(baselinesfolder, 'baseline_material_mass_silicon.csv'),
                                    energymatfile=os.path.join(baselinesfolder, 'baseline_material_energy_silicon.csv'))

r1.scenario['standard_TopCon'].addMaterial(materialname='copper', 
                                    massmatfile=os.path.join(baselinesfolder, 'baseline_material_mass_copper.csv'),
                                    energymatfile=os.path.join(baselinesfolder, 'baseline_material_energy_copper.csv'))

r1.scenario['standard_TopCon'].addMaterial(materialname='silver', 
                                    massmatfile=os.path.join(baselinesfolder, 'baseline_material_mass_silver.csv'),
                                    energymatfile=os.path.join(baselinesfolder, 'baseline_material_energy_silver.csv'))
r1.scenario['standard_TopCon'].addMaterial(materialname='aluminium_frames', 
                                    massmatfile=os.path.join(baselinesfolder, 'baseline_material_mass_aluminium_frames.csv'),
                                    energymatfile=os.path.join(baselinesfolder, 'baseline_material_energy_aluminium_frames.csv'))

r1.scenario['standard_TopCon'].addMaterial(materialname='encapsulant', 
                                    massmatfile=os.path.join(baselinesfolder, 'baseline_material_mass_encapsulant.csv'),
                                    energymatfile=os.path.join(baselinesfolder, 'baseline_material_energy_encapsulant.csv'))

r1.scenario['standard_TopCon'].addMaterial(materialname='backsheet', 
                                    massmatfile=os.path.join(baselinesfolder, 'baseline_material_mass_backsheet.csv'),
                                    energymatfile=os.path.join(baselinesfolder, 'baseline_material_energy_backsheet.csv'))

# %%
r1.createScenario(name='standard_PERC', 
                  massmodulefile=r'baseline_modules_mass_World_SHJ.csv', 
                  energymodulefile = 'baseline_modules_energy.csv' )

r1.scenario['standard_PERC'].addMaterial(materialname='glass', 
                                    massmatfile=os.path.join(baselinesfolder, 'baseline_material_mass_glass.csv'),
                                    energymatfile=os.path.join(baselinesfolder, 'baseline_material_energy_glass.csv'))

r1.scenario['standard_PERC'].addMaterial(materialname='silicon', 
                                    massmatfile=os.path.join(baselinesfolder, 'baseline_material_mass_silicon.csv'),
                                    energymatfile=os.path.join(baselinesfolder, 'baseline_material_energy_silicon.csv'))

r1.scenario['standard_PERC'].addMaterial(materialname='copper', 
                                    massmatfile=os.path.join(baselinesfolder, 'baseline_material_mass_copper.csv'),
                                    energymatfile=os.path.join(baselinesfolder, 'baseline_material_energy_copper.csv'))

r1.scenario['standard_PERC'].addMaterial(materialname='silver', 
                                    massmatfile=os.path.join(baselinesfolder, 'baseline_material_mass_silver.csv'),
                                    energymatfile=os.path.join(baselinesfolder, 'baseline_material_energy_silver.csv'))
r1.scenario['standard_PERC'].addMaterial(materialname='aluminium_frames', 
                                    massmatfile=os.path.join(baselinesfolder, 'baseline_material_mass_aluminium_frames.csv'),
                                    energymatfile=os.path.join(baselinesfolder, 'baseline_material_energy_aluminium_frames.csv'))

r1.scenario['standard_PERC'].addMaterial(materialname='encapsulant', 
                                    massmatfile=os.path.join(baselinesfolder, 'baseline_material_mass_encapsulant.csv'),
                                    energymatfile=os.path.join(baselinesfolder, 'baseline_material_energy_encapsulant.csv'))

r1.scenario['standard_PERC'].addMaterial(materialname='backsheet', 
                                    massmatfile=os.path.join(baselinesfolder, 'baseline_material_mass_backsheet.csv'),
                                    energymatfile=os.path.join(baselinesfolder, 'baseline_material_energy_backsheet.csv'))

# %%
r1.createScenario(name='standard_CdTe', 
                  massmodulefile=r'baseline_modules_mass_World_SHJ.csv', 
                  energymodulefile = 'baseline_modules_energy.csv' )

r1.scenario['standard_CdTe'].addMaterial(materialname='glass', 
                                    massmatfile=os.path.join(baselinesfolder, 'baseline_material_mass_glass.csv'),
                                    energymatfile=os.path.join(baselinesfolder, 'baseline_material_energy_glass.csv'))

r1.scenario['standard_CdTe'].addMaterial(materialname='cadmium', 
                                    massmatfile=os.path.join(baselinesfolder, 'baseline_material_mass_cadmium.csv'),
                                    energymatfile=os.path.join(baselinesfolder, 'baseline_material_energy_cadmium.csv'))

r1.scenario['standard_CdTe'].addMaterial(materialname='tellurium', 
                                    massmatfile=os.path.join(baselinesfolder, 'baseline_material_mass_tellurium.csv'),
                                    energymatfile=os.path.join(baselinesfolder, 'baseline_material_energy_tellurium.csv'))

r1.scenario['standard_CdTe'].addMaterial(materialname='copper', 
                                    massmatfile=os.path.join(baselinesfolder, 'baseline_material_mass_copper.csv'),
                                    energymatfile=os.path.join(baselinesfolder, 'baseline_material_energy_copper.csv'))

r1.scenario['standard_CdTe'].addMaterial(materialname='aluminium_frames', 
                                    massmatfile=os.path.join(baselinesfolder, 'baseline_material_mass_aluminium_frames_cdte.csv'),
                                    energymatfile=os.path.join(baselinesfolder, 'baseline_material_energy_aluminium_frames_cdte.csv'))

r1.scenario['standard_CdTe'].addMaterial(materialname='encapsulant', 
                                    massmatfile=os.path.join(baselinesfolder, 'baseline_material_mass_encapsulant_cdte.csv'),
                                    energymatfile=os.path.join(baselinesfolder, 'baseline_material_energy_encapsulant_cdte.csv'))

# %%
r1.createScenario(name='WR_SHJ', 
                  massmodulefile=r'baseline_modules_mass_World.csv', 
                  energymodulefile = 'baseline_modules_energy.csv' )

r1.scenario['WR_SHJ'].addMaterial(materialname='glass', 
                                    massmatfile=os.path.join(baselinesfolder, 'baseline_material_mass_glass.csv'),
                                    energymatfile=os.path.join(baselinesfolder, 'baseline_material_energy_glass.csv'))

r1.scenario['WR_SHJ'].addMaterial(materialname='silicon', 
                                    massmatfile=os.path.join(baselinesfolder, 'baseline_material_mass_silicon.csv'),
                                    energymatfile=os.path.join(baselinesfolder, 'baseline_material_energy_silicon.csv'))

r1.scenario['WR_SHJ'].addMaterial(materialname='copper', 
                                    massmatfile=os.path.join(baselinesfolder, 'baseline_material_mass_copper.csv'),
                                    energymatfile=os.path.join(baselinesfolder, 'baseline_material_energy_copper.csv'))

r1.scenario['WR_SHJ'].addMaterial(materialname='silver', 
                                    massmatfile=os.path.join(baselinesfolder, 'baseline_material_mass_silver.csv'),
                                    energymatfile=os.path.join(baselinesfolder, 'baseline_material_energy_silver.csv'))
r1.scenario['WR_SHJ'].addMaterial(materialname='aluminium_frames', 
                                    massmatfile=os.path.join(baselinesfolder, 'baseline_material_mass_aluminium_frames.csv'),
                                    energymatfile=os.path.join(baselinesfolder, 'baseline_material_energy_aluminium_frames.csv'))

r1.scenario['WR_SHJ'].addMaterial(materialname='encapsulant', 
                                    massmatfile=os.path.join(baselinesfolder, 'baseline_material_mass_encapsulant.csv'),
                                    energymatfile=os.path.join(baselinesfolder, 'baseline_material_energy_encapsulant.csv'))

r1.scenario['WR_SHJ'].addMaterial(materialname='backsheet', 
                                    massmatfile=os.path.join(baselinesfolder, 'baseline_material_mass_backsheet.csv'),
                                    energymatfile=os.path.join(baselinesfolder, 'baseline_material_energy_backsheet.csv'))
# Out:
# 70
# 71
# 72
# 73
# 74
# 75
# 76
# 77
# 78
# 79
# 80
# 81
# 82
# 83
# 84
# 85
# 86
# 87
# 88
# 89
# 90
# 91
# 92
# 93
# 94
# 95
# 96
# 97
# 98
# 99
# 100

# %%
r1.calculateFlows(scenarios='standard', reducecapacity=False, bifacialityfactors=bififactorsfile)

r1.calculateFlows(scenarios=f, reducecapacity=False, bifacialityfactors=bifiPathDict[f])
# Out:
# >>>> Calculating Material Flows <<<<
#
# Working on Scenario:  standard
# ********************
# Finished Area+Power Generation Calculations
# ==> Working on Material :  glass
# ==> Working on Material :  silicon
# ==> Working on Material :  copper
# ==> Working on Material :  silver
# ==> Working on Material :  aluminium_frames
# ==> Working on Material :  encapsulant
# ==> Working on Material :  backsheet
#
#
# >>>> Calculating Energy Flows <<<<
#
# Working on Scenario:  standard
# ********************
# ==> Working on Energy for Material :  glass
# ==> Working on Energy for Material :  silicon
# ==> Working on Energy for Material :  copper
# ==> Working on Energy for Material :  silver
# ==> Working on Energy for Material :  aluminium_frames
# ==> Working on Energy for Material :  encapsulant
# ==> Working on Energy for Material :  backsheet
# >>>> Calculating Material Flows <<<<
#
# Working on Scenario:  70
# ********************
# Finished Area+Power Generation Calculations
# ==> Working on Material :  glass
# ==> Working on Material :  silicon
# ==> Working on Material :  copper
# ==> Working on Material :  silver
# ==> Working on Material :  aluminium_frames
# ==> Working on Material :  encapsulant
# ==> Working on Material :  backsheet
#
#
# >>>> Calculating Energy Flows <<<<
#
# Working on Scenario:  70
# ********************
# ==> Working on Energy for Material :  glass
# ==> Working on Energy for Material :  silicon
# ==> Working on Energy for Material :  copper
# ==> Working on Energy for Material :  silver
# ==> Working on Energy for Material :  aluminium_frames
# ==> Working on Energy for Material :  encapsulant
# ==> Working on Energy for Material :  backsheet
# >>>> Calculating Material Flows <<<<
#
# Working on Scenario:  71
# ********************
# Finished Area+Power Generation Calculations
# ==> Working on Material :  glass
# ==> Working on Material :  silicon
# ==> Working on Material :  copper
# ==> Working on Material :  silver
# ==> Working on Material :  aluminium_frames
# ==> Working on Material :  encapsulant
# ==> Working on Material :  backsheet
#
#
# >>>> Calculating Energy Flows <<<<
#
# Working on Scenario:  71
# ********************
# ==> Working on Energy for Material :  glass
# ==> Working on Energy for Material :  silicon
# ==> Working on Energy for Material :  copper
# ==> Working on Energy for Material :  silver
# ==> Working on Energy for Material :  aluminium_frames
# ==> Working on Energy for Material :  encapsulant
# ==> Working on Energy for Material :  backsheet
# >>>> Calculating Material Flows <<<<
#
# Working on Scenario:  72
# ********************
# Finished Area+Power Generation Calculations
# ==> Working on Material :  glass
# ==> Working on Material :  silicon
# ==> Working on Material :  copper
# ==> Working on Material :  silver
# ==> Working on Material :  aluminium_frames
# ==> Working on Material :  encapsulant
# ==> Working on Material :  backsheet
#
#
# >>>> Calculating Energy Flows <<<<
#
# Working on Scenario:  72
# ********************
# ==> Working on Energy for Material :  glass
# ==> Working on Energy for Material :  silicon
# ==> Working on Energy for Material :  copper
# ==> Working on Energy for Material :  silver
# ==> Working on Energy for Material :  aluminium_frames
# ==> Working on Energy for Material :  encapsulant
# ==> Working on Energy for Material :  backsheet
# >>>> Calculating Material Flows <<<<
#
# Working on Scenario:  73
# ********************
# Finished Area+Power Generation Calculations
# ==> Working on Material :  glass
# ==> Working on Material :  silicon
# ==> Working on Material :  copper
# ==> Working on Material :  silver
# ==> Working on Material :  aluminium_frames
# ==> Working on Material :  encapsulant
# ==> Working on Material :  backsheet
#
#
# >>>> Calculating Energy Flows <<<<
#
# Working on Scenario:  73
# ********************
# ==> Working on Energy for Material :  glass
# ==> Working on Energy for Material :  silicon
# ==> Working on Energy for Material :  copper
# ==> Working on Energy for Material :  silver
# ==> Working on Energy for Material :  aluminium_frames
# ==> Working on Energy for Material :  encapsulant
# ==> Working on Energy for Material :  backsheet
# >>>> Calculating Material Flows <<<<
#
# Working on Scenario:  74
# ********************
# Finished Area+Power Generation Calculations
# ==> Working on Material :  glass
# ==> Working on Material :  silicon
# ==> Working on Material :  copper
# ==> Working on Material :  silver
# ==> Working on Material :  aluminium_frames
# ==> Working on Material :  encapsulant
# ==> Working on Material :  backsheet
#
#
# >>>> Calculating Energy Flows <<<<
#
# Working on Scenario:  74
# ********************
# ==> Working on Energy for Material :  glass
# ==> Working on Energy for Material :  silicon
# ==> Working on Energy for Material :  copper
# ==> Working on Energy for Material :  silver
# ==> Working on Energy for Material :  aluminium_frames
# ==> Working on Energy for Material :  encapsulant
# ==> Working on Energy for Material :  backsheet
# >>>> Calculating Material Flows <<<<
#
# Working on Scenario:  75
# ********************
# Finished Area+Power Generation Calculations
# ==> Working on Material :  glass
# ==> Working on Material :  silicon
# ==> Working on Material :  copper
# ==> Working on Material :  silver
# ==> Working on Material :  aluminium_frames
# ==> Working on Material :  encapsulant
# ==> Working on Material :  backsheet
#
#
# >>>> Calculating Energy Flows <<<<
#
# Working on Scenario:  75
# ********************
# ==> Working on Energy for Material :  glass
# ==> Working on Energy for Material :  silicon
# ==> Working on Energy for Material :  copper
# ==> Working on Energy for Material :  silver
# ==> Working on Energy for Material :  aluminium_frames
# ==> Working on Energy for Material :  encapsulant
# ==> Working on Energy for Material :  backsheet
# >>>> Calculating Material Flows <<<<
#
# Working on Scenario:  76
# ********************
# Finished Area+Power Generation Calculations
# ==> Working on Material :  glass
# ==> Working on Material :  silicon
# ==> Working on Material :  copper
# ==> Working on Material :  silver
# ==> Working on Material :  aluminium_frames
# ==> Working on Material :  encapsulant
# ==> Working on Material :  backsheet
#
#
# >>>> Calculating Energy Flows <<<<
#
# Working on Scenario:  76
# ********************
# ==> Working on Energy for Material :  glass
# ==> Working on Energy for Material :  silicon
# ==> Working on Energy for Material :  copper
# ==> Working on Energy for Material :  silver
# ==> Working on Energy for Material :  aluminium_frames
# ==> Working on Energy for Material :  encapsulant
# ==> Working on Energy for Material :  backsheet
# >>>> Calculating Material Flows <<<<
#
# Working on Scenario:  77
# ********************
# Finished Area+Power Generation Calculations
# ==> Working on Material :  glass
# ==> Working on Material :  silicon
# ==> Working on Material :  copper
# ==> Working on Material :  silver
# ==> Working on Material :  aluminium_frames
# ==> Working on Material :  encapsulant
# ==> Working on Material :  backsheet
#
#
# >>>> Calculating Energy Flows <<<<
#
# Working on Scenario:  77
# ********************
# ==> Working on Energy for Material :  glass
# ==> Working on Energy for Material :  silicon
# ==> Working on Energy for Material :  copper
# ==> Working on Energy for Material :  silver
# ==> Working on Energy for Material :  aluminium_frames
# ==> Working on Energy for Material :  encapsulant
# ==> Working on Energy for Material :  backsheet
# >>>> Calculating Material Flows <<<<
#
# Working on Scenario:  78
# ********************
# Finished Area+Power Generation Calculations
# ==> Working on Material :  glass
# ==> Working on Material :  silicon
# ==> Working on Material :  copper
# ==> Working on Material :  silver
# ==> Working on Material :  aluminium_frames
# ==> Working on Material :  encapsulant
# ==> Working on Material :  backsheet
#
#
# >>>> Calculating Energy Flows <<<<
#
# Working on Scenario:  78
# ********************
# ==> Working on Energy for Material :  glass
# ==> Working on Energy for Material :  silicon
# ==> Working on Energy for Material :  copper
# ==> Working on Energy for Material :  silver
# ==> Working on Energy for Material :  aluminium_frames
# ==> Working on Energy for Material :  encapsulant
# ==> Working on Energy for Material :  backsheet
# >>>> Calculating Material Flows <<<<
#
# Working on Scenario:  79
# ********************
# Finished Area+Power Generation Calculations
# ==> Working on Material :  glass
# ==> Working on Material :  silicon
# ==> Working on Material :  copper
# ==> Working on Material :  silver
# ==> Working on Material :  aluminium_frames
# ==> Working on Material :  encapsulant
# ==> Working on Material :  backsheet
#
#
# >>>> Calculating Energy Flows <<<<
#
# Working on Scenario:  79
# ********************
# ==> Working on Energy for Material :  glass
# ==> Working on Energy for Material :  silicon
# ==> Working on Energy for Material :  copper
# ==> Working on Energy for Material :  silver
# ==> Working on Energy for Material :  aluminium_frames
# ==> Working on Energy for Material :  encapsulant
# ==> Working on Energy for Material :  backsheet
# >>>> Calculating Material Flows <<<<
#
# Working on Scenario:  80
# ********************
# Finished Area+Power Generation Calculations
# ==> Working on Material :  glass
# ==> Working on Material :  silicon
# ==> Working on Material :  copper
# ==> Working on Material :  silver
# ==> Working on Material :  aluminium_frames
# ==> Working on Material :  encapsulant
# ==> Working on Material :  backsheet
#
#
# >>>> Calculating Energy Flows <<<<
#
# Working on Scenario:  80
# ********************
# ==> Working on Energy for Material :  glass
# ==> Working on Energy for Material :  silicon
# ==> Working on Energy for Material :  copper
# ==> Working on Energy for Material :  silver
# ==> Working on Energy for Material :  aluminium_frames
# ==> Working on Energy for Material :  encapsulant
# ==> Working on Energy for Material :  backsheet
# >>>> Calculating Material Flows <<<<
#
# Working on Scenario:  81
# ********************
# Finished Area+Power Generation Calculations
# ==> Working on Material :  glass
# ==> Working on Material :  silicon
# ==> Working on Material :  copper
# ==> Working on Material :  silver
# ==> Working on Material :  aluminium_frames
# ==> Working on Material :  encapsulant
# ==> Working on Material :  backsheet
#
#
# >>>> Calculating Energy Flows <<<<
#
# Working on Scenario:  81
# ********************
# ==> Working on Energy for Material :  glass
# ==> Working on Energy for Material :  silicon
# ==> Working on Energy for Material :  copper
# ==> Working on Energy for Material :  silver
# ==> Working on Energy for Material :  aluminium_frames
# ==> Working on Energy for Material :  encapsulant
# ==> Working on Energy for Material :  backsheet
# >>>> Calculating Material Flows <<<<
#
# Working on Scenario:  82
# ********************
# Finished Area+Power Generation Calculations
# ==> Working on Material :  glass
# ==> Working on Material :  silicon
# ==> Working on Material :  copper
# ==> Working on Material :  silver
# ==> Working on Material :  aluminium_frames
# ==> Working on Material :  encapsulant
# ==> Working on Material :  backsheet
#
#
# >>>> Calculating Energy Flows <<<<
#
# Working on Scenario:  82
# ********************
# ==> Working on Energy for Material :  glass
# ==> Working on Energy for Material :  silicon
# ==> Working on Energy for Material :  copper
# ==> Working on Energy for Material :  silver
# ==> Working on Energy for Material :  aluminium_frames
# ==> Working on Energy for Material :  encapsulant
# ==> Working on Energy for Material :  backsheet
# >>>> Calculating Material Flows <<<<
#
# Working on Scenario:  83
# ********************
# Finished Area+Power Generation Calculations
# ==> Working on Material :  glass
# ==> Working on Material :  silicon
# ==> Working on Material :  copper
# ==> Working on Material :  silver
# ==> Working on Material :  aluminium_frames
# ==> Working on Material :  encapsulant
# ==> Working on Material :  backsheet
#
#
# >>>> Calculating Energy Flows <<<<
#
# Working on Scenario:  83
# ********************
# ==> Working on Energy for Material :  glass
# ==> Working on Energy for Material :  silicon
# ==> Working on Energy for Material :  copper
# ==> Working on Energy for Material :  silver
# ==> Working on Energy for Material :  aluminium_frames
# ==> Working on Energy for Material :  encapsulant
# ==> Working on Energy for Material :  backsheet
# >>>> Calculating Material Flows <<<<
#
# Working on Scenario:  84
# ********************
# Finished Area+Power Generation Calculations
# ==> Working on Material :  glass
# ==> Working on Material :  silicon
# ==> Working on Material :  copper
# ==> Working on Material :  silver
# ==> Working on Material :  aluminium_frames
# ==> Working on Material :  encapsulant
# ==> Working on Material :  backsheet
#
#
# >>>> Calculating Energy Flows <<<<
#
# Working on Scenario:  84
# ********************
# ==> Working on Energy for Material :  glass
# ==> Working on Energy for Material :  silicon
# ==> Working on Energy for Material :  copper
# ==> Working on Energy for Material :  silver
# ==> Working on Energy for Material :  aluminium_frames
# ==> Working on Energy for Material :  encapsulant
# ==> Working on Energy for Material :  backsheet
# >>>> Calculating Material Flows <<<<
#
# Working on Scenario:  85
# ********************
# Finished Area+Power Generation Calculations
# ==> Working on Material :  glass
# ==> Working on Material :  silicon
# ==> Working on Material :  copper
# ==> Working on Material :  silver
# ==> Working on Material :  aluminium_frames
# ==> Working on Material :  encapsulant
# ==> Working on Material :  backsheet
#
#
# >>>> Calculating Energy Flows <<<<
#
# Working on Scenario:  85
# ********************
# ==> Working on Energy for Material :  glass
# ==> Working on Energy for Material :  silicon
# ==> Working on Energy for Material :  copper
# ==> Working on Energy for Material :  silver
# ==> Working on Energy for Material :  aluminium_frames
# ==> Working on Energy for Material :  encapsulant
# ==> Working on Energy for Material :  backsheet
# >>>> Calculating Material Flows <<<<
#
# Working on Scenario:  86
# ********************
# Finished Area+Power Generation Calculations
# ==> Working on Material :  glass
# ==> Working on Material :  silicon
# ==> Working on Material :  copper
# ==> Working on Material :  silver
# ==> Working on Material :  aluminium_frames
# ==> Working on Material :  encapsulant
# ==> Working on Material :  backsheet
#
#
# >>>> Calculating Energy Flows <<<<
#
# Working on Scenario:  86
# ********************
# ==> Working on Energy for Material :  glass
# ==> Working on Energy for Material :  silicon
# ==> Working on Energy for Material :  copper
# ==> Working on Energy for Material :  silver
# ==> Working on Energy for Material :  aluminium_frames
# ==> Working on Energy for Material :  encapsulant
# ==> Working on Energy for Material :  backsheet
# >>>> Calculating Material Flows <<<<
#
# Working on Scenario:  87
# ********************
# Finished Area+Power Generation Calculations
# ==> Working on Material :  glass
# ==> Working on Material :  silicon
# ==> Working on Material :  copper
# ==> Working on Material :  silver
# ==> Working on Material :  aluminium_frames
# ==> Working on Material :  encapsulant
# ==> Working on Material :  backsheet
#
#
# >>>> Calculating Energy Flows <<<<
#
# Working on Scenario:  87
# ********************
# ==> Working on Energy for Material :  glass
# ==> Working on Energy for Material :  silicon
# ==> Working on Energy for Material :  copper
# ==> Working on Energy for Material :  silver
# ==> Working on Energy for Material :  aluminium_frames
# ==> Working on Energy for Material :  encapsulant
# ==> Working on Energy for Material :  backsheet
# >>>> Calculating Material Flows <<<<
#
# Working on Scenario:  88
# ********************
# Finished Area+Power Generation Calculations
# ==> Working on Material :  glass
# ==> Working on Material :  silicon
# ==> Working on Material :  copper
# ==> Working on Material :  silver
# ==> Working on Material :  aluminium_frames
# ==> Working on Material :  encapsulant
# ==> Working on Material :  backsheet
#
#
# >>>> Calculating Energy Flows <<<<
#
# Working on Scenario:  88
# ********************
# ==> Working on Energy for Material :  glass
# ==> Working on Energy for Material :  silicon
# ==> Working on Energy for Material :  copper
# ==> Working on Energy for Material :  silver
# ==> Working on Energy for Material :  aluminium_frames
# ==> Working on Energy for Material :  encapsulant
# ==> Working on Energy for Material :  backsheet
# >>>> Calculating Material Flows <<<<
#
# Working on Scenario:  89
# ********************
# Finished Area+Power Generation Calculations
# ==> Working on Material :  glass
# ==> Working on Material :  silicon
# ==> Working on Material :  copper
# ==> Working on Material :  silver
# ==> Working on Material :  aluminium_frames
# ==> Working on Material :  encapsulant
# ==> Working on Material :  backsheet
#
#
# >>>> Calculating Energy Flows <<<<
#
# Working on Scenario:  89
# ********************
# ==> Working on Energy for Material :  glass
# ==> Working on Energy for Material :  silicon
# ==> Working on Energy for Material :  copper
# ==> Working on Energy for Material :  silver
# ==> Working on Energy for Material :  aluminium_frames
# ==> Working on Energy for Material :  encapsulant
# ==> Working on Energy for Material :  backsheet
# >>>> Calculating Material Flows <<<<
#
# Working on Scenario:  90
# ********************
# Finished Area+Power Generation Calculations
# ==> Working on Material :  glass
# ==> Working on Material :  silicon
# ==> Working on Material :  copper
# ==> Working on Material :  silver
# ==> Working on Material :  aluminium_frames
# ==> Working on Material :  encapsulant
# ==> Working on Material :  backsheet
#
#
# >>>> Calculating Energy Flows <<<<
#
# Working on Scenario:  90
# ********************
# ==> Working on Energy for Material :  glass
# ==> Working on Energy for Material :  silicon
# ==> Working on Energy for Material :  copper
# ==> Working on Energy for Material :  silver
# ==> Working on Energy for Material :  aluminium_frames
# ==> Working on Energy for Material :  encapsulant
# ==> Working on Energy for Material :  backsheet
# >>>> Calculating Material Flows <<<<
#
# Working on Scenario:  91
# ********************
# Finished Area+Power Generation Calculations
# ==> Working on Material :  glass
# ==> Working on Material :  silicon
# ==> Working on Material :  copper
# ==> Working on Material :  silver
# ==> Working on Material :  aluminium_frames
# ==> Working on Material :  encapsulant
# ==> Working on Material :  backsheet
#
#
# >>>> Calculating Energy Flows <<<<
#
# Working on Scenario:  91
# ********************
# ==> Working on Energy for Material :  glass
# ==> Working on Energy for Material :  silicon
# ==> Working on Energy for Material :  copper
# ==> Working on Energy for Material :  silver
# ==> Working on Energy for Material :  aluminium_frames
# ==> Working on Energy for Material :  encapsulant
# ==> Working on Energy for Material :  backsheet
# >>>> Calculating Material Flows <<<<
#
# Working on Scenario:  92
# ********************
# Finished Area+Power Generation Calculations
# ==> Working on Material :  glass
# ==> Working on Material :  silicon
# ==> Working on Material :  copper
# ==> Working on Material :  silver
# ==> Working on Material :  aluminium_frames
# ==> Working on Material :  encapsulant
# ==> Working on Material :  backsheet
#
#
# >>>> Calculating Energy Flows <<<<
#
# Working on Scenario:  92
# ********************
# ==> Working on Energy for Material :  glass
# ==> Working on Energy for Material :  silicon
# ==> Working on Energy for Material :  copper
# ==> Working on Energy for Material :  silver
# ==> Working on Energy for Material :  aluminium_frames
# ==> Working on Energy for Material :  encapsulant
# ==> Working on Energy for Material :  backsheet
# >>>> Calculating Material Flows <<<<
#
# Working on Scenario:  93
# ********************
# Finished Area+Power Generation Calculations
# ==> Working on Material :  glass
# ==> Working on Material :  silicon
# ==> Working on Material :  copper
# ==> Working on Material :  silver
# ==> Working on Material :  aluminium_frames
# ==> Working on Material :  encapsulant
# ==> Working on Material :  backsheet
#
#
# >>>> Calculating Energy Flows <<<<
#
# Working on Scenario:  93
# ********************
# ==> Working on Energy for Material :  glass
# ==> Working on Energy for Material :  silicon
# ==> Working on Energy for Material :  copper
# ==> Working on Energy for Material :  silver
# ==> Working on Energy for Material :  aluminium_frames
# ==> Working on Energy for Material :  encapsulant
# ==> Working on Energy for Material :  backsheet
# >>>> Calculating Material Flows <<<<
#
# Working on Scenario:  94
# ********************
# Finished Area+Power Generation Calculations
# ==> Working on Material :  glass
# ==> Working on Material :  silicon
# ==> Working on Material :  copper
# ==> Working on Material :  silver
# ==> Working on Material :  aluminium_frames
# ==> Working on Material :  encapsulant
# ==> Working on Material :  backsheet
#
#
# >>>> Calculating Energy Flows <<<<
#
# Working on Scenario:  94
# ********************
# ==> Working on Energy for Material :  glass
# ==> Working on Energy for Material :  silicon
# ==> Working on Energy for Material :  copper
# ==> Working on Energy for Material :  silver
# ==> Working on Energy for Material :  aluminium_frames
# ==> Working on Energy for Material :  encapsulant
# ==> Working on Energy for Material :  backsheet
# >>>> Calculating Material Flows <<<<
#
# Working on Scenario:  95
# ********************
# Finished Area+Power Generation Calculations
# ==> Working on Material :  glass
# ==> Working on Material :  silicon
# ==> Working on Material :  copper
# ==> Working on Material :  silver
# ==> Working on Material :  aluminium_frames
# ==> Working on Material :  encapsulant
# ==> Working on Material :  backsheet
#
#
# >>>> Calculating Energy Flows <<<<
#
# Working on Scenario:  95
# ********************
# ==> Working on Energy for Material :  glass
# ==> Working on Energy for Material :  silicon
# ==> Working on Energy for Material :  copper
# ==> Working on Energy for Material :  silver
# ==> Working on Energy for Material :  aluminium_frames
# ==> Working on Energy for Material :  encapsulant
# ==> Working on Energy for Material :  backsheet
# >>>> Calculating Material Flows <<<<
#
# Working on Scenario:  96
# ********************
# Finished Area+Power Generation Calculations
# ==> Working on Material :  glass
# ==> Working on Material :  silicon
# ==> Working on Material :  copper
# ==> Working on Material :  silver
# ==> Working on Material :  aluminium_frames
# ==> Working on Material :  encapsulant
# ==> Working on Material :  backsheet
#
#
# >>>> Calculating Energy Flows <<<<
#
# Working on Scenario:  96
# ********************
# ==> Working on Energy for Material :  glass
# ==> Working on Energy for Material :  silicon
# ==> Working on Energy for Material :  copper
# ==> Working on Energy for Material :  silver
# ==> Working on Energy for Material :  aluminium_frames
# ==> Working on Energy for Material :  encapsulant
# ==> Working on Energy for Material :  backsheet
# >>>> Calculating Material Flows <<<<
#
# Working on Scenario:  97
# ********************
# Finished Area+Power Generation Calculations
# ==> Working on Material :  glass
# ==> Working on Material :  silicon
# ==> Working on Material :  copper
# ==> Working on Material :  silver
# ==> Working on Material :  aluminium_frames
# ==> Working on Material :  encapsulant
# ==> Working on Material :  backsheet
#
#
# >>>> Calculating Energy Flows <<<<
#
# Working on Scenario:  97
# ********************
# ==> Working on Energy for Material :  glass
# ==> Working on Energy for Material :  silicon
# ==> Working on Energy for Material :  copper
# ==> Working on Energy for Material :  silver
# ==> Working on Energy for Material :  aluminium_frames
# ==> Working on Energy for Material :  encapsulant
# ==> Working on Energy for Material :  backsheet
# >>>> Calculating Material Flows <<<<
#
# Working on Scenario:  98
# ********************
# Finished Area+Power Generation Calculations
# ==> Working on Material :  glass
# ==> Working on Material :  silicon
# ==> Working on Material :  copper
# ==> Working on Material :  silver
# ==> Working on Material :  aluminium_frames
# ==> Working on Material :  encapsulant
# ==> Working on Material :  backsheet
#
#
# >>>> Calculating Energy Flows <<<<
#
# Working on Scenario:  98
# ********************
# ==> Working on Energy for Material :  glass
# ==> Working on Energy for Material :  silicon
# ==> Working on Energy for Material :  copper
# ==> Working on Energy for Material :  silver
# ==> Working on Energy for Material :  aluminium_frames
# ==> Working on Energy for Material :  encapsulant
# ==> Working on Energy for Material :  backsheet
# >>>> Calculating Material Flows <<<<
#
# Working on Scenario:  99
# ********************
# Finished Area+Power Generation Calculations
# ==> Working on Material :  glass
# ==> Working on Material :  silicon
# ==> Working on Material :  copper
# ==> Working on Material :  silver
# ==> Working on Material :  aluminium_frames
# ==> Working on Material :  encapsulant
# ==> Working on Material :  backsheet
#
#
# >>>> Calculating Energy Flows <<<<
#
# Working on Scenario:  99
# ********************
# ==> Working on Energy for Material :  glass
# ==> Working on Energy for Material :  silicon
# ==> Working on Energy for Material :  copper
# ==> Working on Energy for Material :  silver
# ==> Working on Energy for Material :  aluminium_frames
# ==> Working on Energy for Material :  encapsulant
# ==> Working on Energy for Material :  backsheet
# >>>> Calculating Material Flows <<<<
#
# Working on Scenario:  100
# ********************
# Finished Area+Power Generation Calculations
# ==> Working on Material :  glass
# ==> Working on Material :  silicon
# ==> Working on Material :  copper
# ==> Working on Material :  silver
# ==> Working on Material :  aluminium_frames
# ==> Working on Material :  encapsulant
# ==> Working on Material :  backsheet
#
#
# >>>> Calculating Energy Flows <<<<
#
# Working on Scenario:  100
# ********************
# ==> Working on Energy for Material :  glass
# ==> Working on Energy for Material :  silicon
# ==> Working on Energy for Material :  copper
# ==> Working on Energy for Material :  silver
# ==> Working on Energy for Material :  aluminium_frames
# ==> Working on Energy for Material :  encapsulant
# ==> Working on Energy for Material :  backsheet

# %%
USyearly, UScum = r1.aggregateResults()
# Out:
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2166: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_Module_'+self.name+'_'+scen] = USyearly[filter_col].sum(axis=1)
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2166: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_Module_'+self.name+'_'+scen] = USyearly[filter_col].sum(axis=1)
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2166: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_Module_'+self.name+'_'+scen] = USyearly[filter_col].sum(axis=1)
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2166: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_Module_'+self.name+'_'+scen] = USyearly[filter_col].sum(axis=1)
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2166: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_Module_'+self.name+'_'+scen] = USyearly[filter_col].sum(axis=1)
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2166: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_Module_'+self.name+'_'+scen] = USyearly[filter_col].sum(axis=1)
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2166: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_Module_'+self.name+'_'+scen] = USyearly[filter_col].sum(axis=1)
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2166: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_Module_'+self.name+'_'+scen] = USyearly[filter_col].sum(axis=1)
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2166: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_Module_'+self.name+'_'+scen] = USyearly[filter_col].sum(axis=1)
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2166: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_Module_'+self.name+'_'+scen] = USyearly[filter_col].sum(axis=1)
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2166: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_Module_'+self.name+'_'+scen] = USyearly[filter_col].sum(axis=1)
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2166: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_Module_'+self.name+'_'+scen] = USyearly[filter_col].sum(axis=1)
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2166: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_Module_'+self.name+'_'+scen] = USyearly[filter_col].sum(axis=1)
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2166: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_Module_'+self.name+'_'+scen] = USyearly[filter_col].sum(axis=1)
# ...
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2166: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_Module_'+self.name+'_'+scen] = USyearly[filter_col].sum(axis=1)
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2166: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_Module_'+self.name+'_'+scen] = USyearly[filter_col].sum(axis=1)
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2166: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_Module_'+self.name+'_'+scen] = USyearly[filter_col].sum(axis=1)
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2166: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_Module_'+self.name+'_'+scen] = USyearly[filter_col].sum(axis=1)
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2164: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_'+mat+'_'+self.name+'_'+scen] = self.scenario[scen].material[mat].matdataOut_m[keywd]
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2166: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   USyearly[nicekey+'_Module_'+self.name+'_'+scen] = USyearly[filter_col].sum(axis=1)

# %%
USyearly.to_csv('USyearly.csv')
UScum.to_csv('UScum.csv')

# %%
r1.scenario['70'].dataOut_m['Effective_Capacity_[W]']
# Out:
# 0     6.759900e+07
# 1     1.434564e+08
# 2     2.534327e+08
# 3     3.856050e+08
# 4     5.628316e+08
# 5     8.097003e+08
# 6     1.063819e+09
# 7     1.381827e+09
# 8     1.874730e+09
# 9     2.893757e+09
# 10    4.221901e+09
# 11    5.564267e+09
# 12    7.680125e+09
# 13    1.298740e+10
# 14    1.964349e+10
# 15    3.490537e+10
# 16    6.203061e+10
# 17    8.844993e+10
# 18    1.190442e+11
# 19    1.512672e+11
# 20    1.960973e+11
# 21    2.685883e+11
# 22    3.613874e+11
# 23    4.586786e+11
# 24    5.550939e+11
# 25    6.603129e+11
# 26    7.746113e+11
# 27    8.988597e+11
# 28    1.033945e+12
# 29    1.180600e+12
# 30    1.339803e+12
# 31    1.512872e+12
# 32    1.700976e+12
# 33    1.905345e+12
# 34    2.127130e+12
# 35    2.368010e+12
# 36    2.629925e+12
# 37    2.914129e+12
# 38    3.220634e+12
# 39    3.553064e+12
# 40    3.908068e+12
# 41    4.285852e+12
# 42    4.699276e+12
# 43    5.147607e+12
# 44    5.636256e+12
# 45    6.160473e+12
# 46    6.712783e+12
# 47    7.304299e+12
# 48    7.953140e+12
# 49    8.669392e+12
# 50    9.536057e+12
# 51    1.047927e+13
# 52    1.150578e+13
# 53    1.262291e+13
# 54    1.383861e+13
# 55             NaN
# Name: Effective_Capacity_[W], dtype: float64

# %%
allenergy, energyGen, energy_demands = r1.aggregateEnergyResults()
allenergy.to_csv('Energy_all.csv')
energyGen.to_csv('Energy_Generation.csv')
energy_demands.to_csv('Energy_demands.csv')
# Out:
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2255: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scende_demands.loc[:,colname] = scende_demands.sum(axis=1) #sums module and material energy demands
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2255: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scende_demands.loc[:,colname] = scende_demands.sum(axis=1) #sums module and material energy demands
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2255: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scende_demands.loc[:,colname] = scende_demands.sum(axis=1) #sums module and material energy demands
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2255: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scende_demands.loc[:,colname] = scende_demands.sum(axis=1) #sums module and material energy demands
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2255: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scende_demands.loc[:,colname] = scende_demands.sum(axis=1) #sums module and material energy demands
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2255: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scende_demands.loc[:,colname] = scende_demands.sum(axis=1) #sums module and material energy demands
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2255: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scende_demands.loc[:,colname] = scende_demands.sum(axis=1) #sums module and material energy demands
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2255: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scende_demands.loc[:,colname] = scende_demands.sum(axis=1) #sums module and material energy demands
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2255: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scende_demands.loc[:,colname] = scende_demands.sum(axis=1) #sums module and material energy demands
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2255: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scende_demands.loc[:,colname] = scende_demands.sum(axis=1) #sums module and material energy demands
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2255: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scende_demands.loc[:,colname] = scende_demands.sum(axis=1) #sums module and material energy demands
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2255: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scende_demands.loc[:,colname] = scende_demands.sum(axis=1) #sums module and material energy demands
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2255: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scende_demands.loc[:,colname] = scende_demands.sum(axis=1) #sums module and material energy demands
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2255: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scende_demands.loc[:,colname] = scende_demands.sum(axis=1) #sums module and material energy demands
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2255: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scende_demands.loc[:,colname] = scende_demands.sum(axis=1) #sums module and material energy demands
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2255: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scende_demands.loc[:,colname] = scende_demands.sum(axis=1) #sums module and material energy demands
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2255: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scende_demands.loc[:,colname] = scende_demands.sum(axis=1) #sums module and material energy demands
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2255: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scende_demands.loc[:,colname] = scende_demands.sum(axis=1) #sums module and material energy demands
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2255: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scende_demands.loc[:,colname] = scende_demands.sum(axis=1) #sums module and material energy demands
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2255: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scende_demands.loc[:,colname] = scende_demands.sum(axis=1) #sums module and material energy demands
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2255: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scende_demands.loc[:,colname] = scende_demands.sum(axis=1) #sums module and material energy demands
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2255: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scende_demands.loc[:,colname] = scende_demands.sum(axis=1) #sums module and material energy demands
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2255: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scende_demands.loc[:,colname] = scende_demands.sum(axis=1) #sums module and material energy demands
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2255: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scende_demands.loc[:,colname] = scende_demands.sum(axis=1) #sums module and material energy demands
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2255: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scende_demands.loc[:,colname] = scende_demands.sum(axis=1) #sums module and material energy demands
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2255: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scende_demands.loc[:,colname] = scende_demands.sum(axis=1) #sums module and material energy demands
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2255: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scende_demands.loc[:,colname] = scende_demands.sum(axis=1) #sums module and material energy demands
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2255: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scende_demands.loc[:,colname] = scende_demands.sum(axis=1) #sums module and material energy demands
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2255: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scende_demands.loc[:,colname] = scende_demands.sum(axis=1) #sums module and material energy demands
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2255: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scende_demands.loc[:,colname] = scende_demands.sum(axis=1) #sums module and material energy demands
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2255: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scende_demands.loc[:,colname] = scende_demands.sum(axis=1) #sums module and material energy demands
# C:\Users\sayala\Documents\GitHub\PV_ICE\PV_ICE\main.py:2255: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scende_demands.loc[:,colname] = scende_demands.sum(axis=1) #sums module and material energy demands

# %%
r1.saveSimulation()
r1.pickle_Sim()
# Out:
# :) Saved Input and Output Dataframes
