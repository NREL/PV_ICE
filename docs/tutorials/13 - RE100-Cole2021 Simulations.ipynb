# %% [markdown]
# # US NREL Cole et al 2021 - Quantifying 100% RE by 2050

# %% [markdown]
# Create a folder to store the files

# %%
import os
from pathlib import Path

testfolder = str(Path().resolve().parent.parent / 'PV_ICE' / 'TEMP' / 'Cole2021')

# Another option using relative address; for some operative systems you might need '/' instead of '\'
# testfolder = os.path.abspath(r'..\..\PV_ICE\TEMP')  

print ("Your simulation will be stored in %s" % testfolder)
# Out:
# Your simulation will be stored in C:\Users\hmirletz\Documents\GitHub\PV_ICE\PV_ICE\TEMP\Cole2021

# %% [markdown]
# Specify the materials to add to the simulation.

# %%
MATERIALS = ['glass','silver','silicon', 'copper','aluminium_frames']
MATERIAL = MATERIALS[0]

MODULEBASELINE = r'..\..\baselines\baseline_modules_US_57RE2050.csv'
MODULEBASELINE_High = r'..\..\baselines\baseline_modules_US_100RE2050.csv'

# %%
import PV_ICE
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
PV_ICE.__version__
# Out:
# '0+untagged.458.g8e7b2e3.dirty'

# %%
plt.rcParams.update({'font.size': 22})
plt.rcParams['figure.figsize'] = (12, 5)

# %% [markdown]
# # Run the Simulation

# %%
r1 = PV_ICE.Simulation(name='PV_ICE', path=testfolder)
r1.createScenario(name='base', file=MODULEBASELINE)
for mat in range (0, len(MATERIALS)):
    MATERIALBASELINE = r'..\..\baselines\baseline_material_'+MATERIALS[mat]+'.csv'
    r1.scenario['base'].addMaterial(MATERIALS[mat], file=MATERIALBASELINE)
    
r1.createScenario(name='high', file=MODULEBASELINE_High)
for mat in range (0, len(MATERIALS)):
    MATERIALBASELINE = r'..\..\baselines\baseline_material_'+MATERIALS[mat]+'.csv'
    r1.scenario['high'].addMaterial(MATERIALS[mat], file=MATERIALBASELINE)

r2 = PV_ICE.Simulation(name='bifacialTrend', path=testfolder)
r2.createScenario(name='base', file=MODULEBASELINE)
MATERIALBASELINE = r'..\..\baselines\PVSC_2021\baseline_material_glass_bifacialTrend.csv'
r2.scenario['base'].addMaterial('glass', file=MATERIALBASELINE)
MATERIALBASELINE = r'..\..\baselines\PVSC_2021\baseline_material_aluminium_frames_bifacialTrend.csv'
r2.scenario['base'].addMaterial('aluminium_frames', file=MATERIALBASELINE)
for mat in range (1, len(MATERIALS)-1):
    MATERIALBASELINE = r'..\..\baselines\baseline_material_'+MATERIALS[mat]+'.csv'
    r2.scenario['base'].addMaterial(MATERIALS[mat], file=MATERIALBASELINE)
    
r2.createScenario(name='high', file=MODULEBASELINE_High)
MATERIALBASELINE = r'..\..\baselines\PVSC_2021\baseline_material_glass_bifacialTrend.csv'
r2.scenario['high'].addMaterial('glass', file=MATERIALBASELINE)
MATERIALBASELINE = r'..\..\baselines\PVSC_2021\baseline_material_aluminium_frames_bifacialTrend.csv'
r2.scenario['high'].addMaterial('aluminium_frames', file=MATERIALBASELINE)
for mat in range (1, len(MATERIALS)-1):
    MATERIALBASELINE = r'..\..\baselines\baseline_material_'+MATERIALS[mat]+'.csv'
    r2.scenario['high'].addMaterial(MATERIALS[mat], file=MATERIALBASELINE)

# Irena EL 
r3 = PV_ICE.Simulation(name='Irena_EL', path=testfolder)

r3.createScenario(name='base', file=MODULEBASELINE)
r3.scenario['base'].data['mod_lifetime'] = 40
r3.scenario['base'].data['mod_MFG_eff'] = 100.0
for mat in range (0, len(MATERIALS)):
    MATERIALBASELINE = r'..\..\baselines\baseline_material_'+MATERIALS[mat]+'.csv'
    r3.scenario['base'].addMaterial(MATERIALS[mat], file=MATERIALBASELINE)
    r3.scenario['base'].material[MATERIALS[mat]].materialdata['mat_MFG_eff'] = 100.0   
    r3.scenario['base'].material[MATERIALS[mat]].materialdata['mat_MFG_scrap_Recycled'] = 0.0  

r3.createScenario(name='high', file=MODULEBASELINE_High)
r3.scenario['high'].data['mod_lifetime'] = 40
r3.scenario['high'].data['mod_MFG_eff'] = 100.0
for mat in range (0, len(MATERIALS)):
    MATERIALBASELINE = r'..\..\baselines\baseline_material_'+MATERIALS[mat]+'.csv'
    r3.scenario['high'].addMaterial(MATERIALS[mat], file=MATERIALBASELINE)
    r3.scenario['high'].material[MATERIALS[mat]].materialdata['mat_MFG_eff'] = 100.0   
    r3.scenario['high'].material[MATERIALS[mat]].materialdata['mat_MFG_scrap_Recycled'] = 0.0  

# Irena RL
r4 = PV_ICE.Simulation(name='Irena_RL', path=testfolder)

r4.createScenario(name='base', file=MODULEBASELINE)
r4.scenario['base'].data['mod_lifetime'] = 40
r4.scenario['base'].data['mod_MFG_eff'] = 100.0
for mat in range (0, len(MATERIALS)):
    MATERIALBASELINE = r'..\..\baselines\baseline_material_'+MATERIALS[mat]+'.csv'
    r4.scenario['base'].addMaterial(MATERIALS[mat], file=MATERIALBASELINE)
    r4.scenario['base'].material[MATERIALS[mat]].materialdata['mat_MFG_eff'] = 100.0   
    r4.scenario['base'].material[MATERIALS[mat]].materialdata['mat_MFG_scrap_Recycled'] = 0.0  

r4.createScenario(name='high', file=MODULEBASELINE_High)
r4.scenario['high'].data['mod_lifetime'] = 40
r4.scenario['high'].data['mod_MFG_eff'] = 100.0
for mat in range (0, len(MATERIALS)):
    MATERIALBASELINE = r'..\..\baselines\baseline_material_'+MATERIALS[mat]+'.csv'
    r4.scenario['high'].addMaterial(MATERIALS[mat], file=MATERIALBASELINE)
    r4.scenario['high'].material[MATERIALS[mat]].materialdata['mat_MFG_eff'] = 100.0   
    r4.scenario['high'].material[MATERIALS[mat]].materialdata['mat_MFG_scrap_Recycled'] = 0.0
# Out:
# path = C:\Users\hmirletz\Documents\GitHub\PV_ICE\PV_ICE\TEMP\Cole2021
# path = C:\Users\hmirletz\Documents\GitHub\PV_ICE\PV_ICE\TEMP\Cole2021
# path = C:\Users\hmirletz\Documents\GitHub\PV_ICE\PV_ICE\TEMP\Cole2021
# path = C:\Users\hmirletz\Documents\GitHub\PV_ICE\PV_ICE\TEMP\Cole2021

# %%
list(r1.scenario['base'].data.keys())
# Out:
# ['year',
#  'new_Installed_Capacity_[MW]',
#  'mod_eff',
#  'mod_reliability_t50',
#  'mod_reliability_t90',
#  'mod_degradation',
#  'mod_lifetime',
#  'mod_MFG_eff',
#  'mod_EOL_collection_eff',
#  'mod_EOL_collected_recycled',
#  'mod_Repair',
#  'mod_MerchantTail',
#  'mod_Reuse']

# %%
r1.calculateMassFlow()
r2.calculateMassFlow()

weibullInputParams = {'alpha': 2.49, 'beta':30}  # Early-loss scenario IRENA
r3.calculateMassFlow(weibullInputParams=weibullInputParams)

weibullInputParams = {'alpha': 5.3759, 'beta':30}  # Regular-loss scenario IRENA
r4.calculateMassFlow(weibullInputParams=weibullInputParams)
# Out:
# Working on Scenario:  base
# ********************
# Finished Area+Power Generation Calculations
# ==> Working on Material :  glass
# ==> Working on Material :  silver
# ==> Working on Material :  silicon
# ==> Working on Material :  copper
# ==> Working on Material :  aluminium_frames
# Working on Scenario:  high
# ********************
# Finished Area+Power Generation Calculations
# ==> Working on Material :  glass
# ==> Working on Material :  silver
# ==> Working on Material :  silicon
# ==> Working on Material :  copper
# ==> Working on Material :  aluminium_frames
# Working on Scenario:  base
# ********************
# Finished Area+Power Generation Calculations
# ==> Working on Material :  glass
# ==> Working on Material :  aluminium_frames
# ==> Working on Material :  silver
# ==> Working on Material :  silicon
# ==> Working on Material :  copper
# Working on Scenario:  high
# ********************
# Finished Area+Power Generation Calculations
# ==> Working on Material :  glass
# ==> Working on Material :  aluminium_frames
# ==> Working on Material :  silver
# ==> Working on Material :  silicon
# ==> Working on Material :  copper
# Working on Scenario:  base
# ********************
# Finished Area+Power Generation Calculations
# ==> Working on Material :  glass
# ==> Working on Material :  silver
# ==> Working on Material :  silicon
# ==> Working on Material :  copper
# ==> Working on Material :  aluminium_frames
# Working on Scenario:  high
# ********************
# Finished Area+Power Generation Calculations
# ==> Working on Material :  glass
# ==> Working on Material :  silver
# ==> Working on Material :  silicon
# ==> Working on Material :  copper
# ==> Working on Material :  aluminium_frames
# Working on Scenario:  base
# ********************
# Finished Area+Power Generation Calculations
# ==> Working on Material :  glass
# ==> Working on Material :  silver
# ==> Working on Material :  silicon
# ==> Working on Material :  copper
# ==> Working on Material :  aluminium_frames
# Working on Scenario:  high
# ********************
# Finished Area+Power Generation Calculations
# ==> Working on Material :  glass
# ==> Working on Material :  silver
# ==> Working on Material :  silicon
# ==> Working on Material :  copper
# ==> Working on Material :  aluminium_frames

# %% [markdown]
# ## Creating Summary of results

# %%
objects = [r1, r2, r3, r4]
scenarios = ['base', 'high']

# %%
USyearly=pd.DataFrame()

# %%
keyword='mat_Total_Landfilled'
materials = ['glass', 'silicon', 'silver', 'copper', 'aluminium_frames']

# Loop over objects
for kk in range(0, len(objects)):
    obj = objects[kk]

    # Loop over Scenarios
    for jj in range(0, len(scenarios)):
        case = scenarios[jj]
        
        for ii in range (0, len(materials)):    
            material = materials[ii]
            foo = obj.scenario[case].material[material].materialdata[keyword].copy()
            foo = foo.to_frame(name=material)
            USyearly["Waste_"+material+'_'+obj.name+'_'+case] = foo[material]

        filter_col = [col for col in USyearly if (col.startswith('Waste') and col.endswith(obj.name+'_'+case)) ]
        USyearly['Waste_Module_'+obj.name+'_'+case] = USyearly[filter_col].sum(axis=1)

# Converting to grams to Tons. 
USyearly.head(20)
# Out:
#     Waste_glass_PV_ICE_base  Waste_silicon_PV_ICE_base  \
# 0              3.557465e+07               7.064407e+07
# 1              2.708324e+07               5.272248e+07
# 2              3.215794e+07               6.125064e+07
# 3              3.246804e+07               6.001756e+07
# 4              4.681363e+07               8.317952e+07
# 5              5.956584e+07               9.979721e+07
# 6              8.272290e+07               1.292807e+08
# 7              1.294118e+08               1.907181e+08
# 8              1.887176e+08               2.607935e+08
# 9              3.002429e+08               4.109054e+08
# 10             9.712870e+08               5.421610e+08
# 11             7.829401e+08               5.801720e+08
# 12             8.236658e+08               1.729869e+09
# 13             8.122343e+08               1.679519e+09
# 14             1.124835e+09               2.248071e+09
# 15             1.873490e+09               1.767385e+09
# 16             4.424479e+09               4.194998e+09
# 17             7.995833e+09               7.411307e+09
# 18             1.012265e+10               8.928549e+09
# 19             9.519222e+09               8.055741e+09
#
#     Waste_silver_PV_ICE_base  Waste_copper_PV_ICE_base  \
# 0               1.903224e+05              2.848183e+03
# 1               1.392646e+05              2.169933e+03
# 2               1.590017e+05              2.609763e+03
# 3               1.558401e+05              2.828400e+03
# 4               2.210346e+05              4.625451e+03
# 5               1.985433e+05              7.251887e+03
# 6               2.979944e+05              1.239959e+04
# 7               4.886206e+05              2.206772e+04
# 8               7.523668e+05              3.646577e+04
# 9               1.188847e+06              5.977646e+04
# 10              8.669476e+06              5.191413e+05
# 11              6.273556e+06              3.885719e+05
# 12              1.644644e+06              7.743406e+04
# 13              1.654403e+06              8.811729e+04
# 14              2.274499e+06              1.340193e+05
# 15              2.414865e+06              2.297470e+05
# 16              4.456339e+06              4.923753e+05
# 17              1.129163e+07              1.148255e+06
# 18              1.107252e+07              1.382319e+06
# 19              1.288704e+07              1.580862e+06
#
#     Waste_aluminium_frames_PV_ICE_base  Waste_Module_PV_ICE_base  \
# 0                         3.797870e+06              1.102098e+08
# 1                         2.823082e+06              8.277023e+07
# 2                         3.015525e+06              9.658572e+07
# 3                         2.960336e+06              9.560460e+07
# 4                         4.447433e+06              1.346662e+08
# 5                         6.229870e+06              1.657987e+08
# 6                         9.677156e+06              2.219911e+08
# 7                         1.628803e+07              3.369286e+08
# 8                         2.571493e+07              4.760149e+08
# 9                         4.122395e+07              7.536209e+08
# 10                        2.973426e+08              1.819979e+09
# 11                        2.190589e+08              1.588833e+09
# 12                        6.319147e+07              2.618448e+09
# 13                        6.634735e+07              2.559843e+09
# 14                        9.566111e+07              3.470975e+09
# 15                        1.607333e+08              3.804254e+09
# 16                        3.555811e+08              8.980007e+09
# 17                        7.531884e+08              1.617277e+10
# 18                        7.971335e+08              1.986078e+10
# 19                        8.515391e+08              1.844097e+10
#
#     Waste_glass_PV_ICE_high  Waste_silicon_PV_ICE_high  \
# 0              3.557465e+07               7.064407e+07
# 1              2.708324e+07               5.272248e+07
# 2              3.215794e+07               6.125064e+07
# 3              3.246804e+07               6.001756e+07
# 4              4.681363e+07               8.317952e+07
# 5              5.956584e+07               9.979721e+07
# 6              8.272290e+07               1.292807e+08
# 7              1.294118e+08               1.907181e+08
# 8              1.887176e+08               2.607935e+08
# 9              3.002429e+08               4.109054e+08
# 10             9.712870e+08               5.421610e+08
# 11             7.829401e+08               5.801720e+08
# 12             8.236658e+08               1.729869e+09
# 13             8.122343e+08               1.679519e+09
# 14             1.124835e+09               2.248071e+09
# 15             1.873490e+09               1.767385e+09
# 16             4.424479e+09               4.194998e+09
# 17             7.995833e+09               7.411307e+09
# 18             1.012265e+10               8.928549e+09
# 19             9.519222e+09               8.055741e+09
#
#     Waste_silver_PV_ICE_high  Waste_copper_PV_ICE_high  ...  \
# 0               1.903224e+05              2.848183e+03  ...
# 1               1.392646e+05              2.169933e+03  ...
# 2               1.590017e+05              2.609763e+03  ...
# 3               1.558401e+05              2.828400e+03  ...
# 4               2.210346e+05              4.625451e+03  ...
# 5               1.985433e+05              7.251887e+03  ...
# 6               2.979944e+05              1.239959e+04  ...
# 7               4.886206e+05              2.206772e+04  ...
# 8               7.523668e+05              3.646577e+04  ...
# 9               1.188847e+06              5.977646e+04  ...
# 10              8.669476e+06              5.191413e+05  ...
# 11              6.273556e+06              3.885719e+05  ...
# 12              1.644644e+06              7.743406e+04  ...
# 13              1.654403e+06              8.811729e+04  ...
# 14              2.274499e+06              1.340193e+05  ...
# 15              2.414865e+06              2.297470e+05  ...
# 16              4.456339e+06              4.923753e+05  ...
# 17              1.129163e+07              1.148255e+06  ...
# 18              1.107252e+07              1.382319e+06  ...
# 19              1.288704e+07              1.580862e+06  ...
#
#     Waste_silver_Irena_RL_base  Waste_copper_Irena_RL_base  \
# 0                 0.000000e+00                    0.000000
# 1                 1.008385e-01                    0.006160
# 2                 4.261066e+00                    0.260495
# 3                 4.017959e+01                    2.462628
# 4                 2.045301e+02                   12.580665
# 5                 7.384826e+02                   45.616871
# 6                 2.138385e+03                  132.722250
# 7                 5.307093e+03                  331.248780
# 8                 1.174804e+04                  738.496774
# 9                 2.380407e+04                 1510.149065
# 10                4.494534e+04                 2884.826893
# 11                8.010870e+04                 5216.655640
# 12                1.360825e+05                 9017.821351
# 13                2.219036e+05                15011.080777
# 14                3.492110e+05                24192.335385
# 15                5.325085e+05                37909.286827
# 16                7.892351e+05                57958.731976
# 17                1.139494e+06                86705.485873
# 18                1.605300e+06               127248.593433
# 19                2.209361e+06               183716.644821
#
#     Waste_aluminium_frames_Irena_RL_base  Waste_Module_Irena_RL_base  \
# 0                           0.000000e+00                0.000000e+00
# 1                           3.452903e+00                1.349190e+01
# 2                           1.459467e+02                5.704381e+02
# 3                           1.377322e+03                5.389715e+03
# 4                           7.011592e+03                2.750518e+04
# 5                           2.529173e+04                9.958229e+04
# 6                           7.311216e+04                2.892013e+05
# 7                           1.811314e+05                7.202829e+05
# 8                           4.005756e+05                1.602163e+06
# 9                           8.121137e+05                3.268267e+06
# 10                          1.537328e+06                6.227186e+06
# 11                          2.753421e+06                1.122975e+07
# 12                          4.711651e+06                1.935562e+07
# 13                          7.758910e+06                3.211855e+07
# 14                          1.236155e+07                5.158888e+07
# 15                          1.913242e+07                8.054283e+07
# 16                          2.886041e+07                1.226407e+08
# 17                          4.254152e+07                1.826362e+08
# 18                          6.141906e+07                2.666632e+08
# 19                          8.706153e+07                3.827524e+08
#
#     Waste_glass_Irena_RL_high  Waste_silicon_Irena_RL_high  \
# 0                0.000000e+00                 0.000000e+00
# 1                8.969129e+00                 9.628666e-01
# 2                3.792685e+02                 4.070139e+01
# 3                3.585469e+03                 3.842814e+02
# 4                1.831685e+04                 1.959632e+03
# 5                6.641599e+04                 7.090471e+03
# 6                1.932373e+05                 2.058078e+04
# 7                4.822824e+05                 5.123076e+04
# 8                1.075216e+06                 1.138843e+05
# 9                2.198705e+06                 2.321339e+05
# 10               4.200171e+06                 4.418569e+05
# 11               7.595202e+06                 7.957963e+05
# 12               1.312952e+07                 1.369349e+06
# 13               2.185542e+07                 2.267308e+06
# 14               3.522289e+07                 3.631043e+06
# 15               5.519412e+07                 5.645880e+06
# 16               8.438515e+07                 8.547926e+06
# 17               1.262391e+08                 1.262946e+07
# 18               1.852679e+08                 1.824366e+07
# 19               2.674835e+08                 2.581433e+07
#
#     Waste_silver_Irena_RL_high  Waste_copper_Irena_RL_high  \
# 0                 0.000000e+00                    0.000000
# 1                 1.008385e-01                    0.006160
# 2                 4.261066e+00                    0.260495
# 3                 4.017959e+01                    2.462628
# 4                 2.045301e+02                   12.580665
# 5                 7.384826e+02                   45.616871
# 6                 2.138385e+03                  132.722250
# 7                 5.307093e+03                  331.248780
# 8                 1.174804e+04                  738.496774
# 9                 2.380407e+04                 1510.149065
# 10                4.494534e+04                 2884.826893
# 11                8.010870e+04                 5216.655640
# 12                1.360825e+05                 9017.821351
# 13                2.219036e+05                15011.080777
# 14                3.492110e+05                24192.335385
# 15                5.325085e+05                37909.286827
# 16                7.892351e+05                57958.731976
# 17                1.139494e+06                86705.485873
# 18                1.605300e+06               127248.593433
# 19                2.209361e+06               183716.644821
#
#     Waste_aluminium_frames_Irena_RL_high  Waste_Module_Irena_RL_high
# 0                           0.000000e+00                0.000000e+00
# 1                           3.452903e+00                1.349190e+01
# 2                           1.459467e+02                5.704381e+02
# 3                           1.377322e+03                5.389715e+03
# 4                           7.011592e+03                2.750518e+04
# 5                           2.529173e+04                9.958229e+04
# 6                           7.311216e+04                2.892013e+05
# 7                           1.811314e+05                7.202829e+05
# 8                           4.005756e+05                1.602163e+06
# 9                           8.121137e+05                3.268267e+06
# 10                          1.537328e+06                6.227186e+06
# 11                          2.753421e+06                1.122975e+07
# 12                          4.711651e+06                1.935562e+07
# 13                          7.758910e+06                3.211855e+07
# 14                          1.236155e+07                5.158888e+07
# 15                          1.913242e+07                8.054283e+07
# 16                          2.886041e+07                1.226407e+08
# 17                          4.254152e+07                1.826362e+08
# 18                          6.141906e+07                2.666632e+08
# 19                          8.706153e+07                3.827524e+08
#
# [20 rows x 48 columns]

# %%
keyword='mat_Total_Landfilled'
materials = ['glass', 'silicon', 'silver', 'copper', 'aluminium_frames']

# Loop over objects
for kk in range(0, len(objects)):
    obj = objects[kk]

    # Loop over Scenarios
    for jj in range(0, len(scenarios)):
        case = scenarios[jj]
        
        for ii in range (0, len(materials)):    
            material = materials[ii]
            foo = obj.scenario[case].material[material].materialdata[keyword].copy()
            foo = foo.to_frame(name=material)
            USyearly["Waste_"+material+'_'+obj.name+'_'+case] = foo[material]

        filter_col = [col for col in USyearly if (col.startswith('Waste') and col.endswith(obj.name+'_'+case)) ]
        USyearly['Waste_Module_'+obj.name+'_'+case] = USyearly[filter_col].sum(axis=1)

# Converting to grams to Tons. 
USyearly.head(20)
# Out:
#     Waste_glass_PV_ICE_base  Waste_silicon_PV_ICE_base  \
# 0              3.557465e+07               7.064407e+07
# 1              2.708324e+07               5.272248e+07
# 2              3.215794e+07               6.125064e+07
# 3              3.246804e+07               6.001756e+07
# 4              4.681363e+07               8.317952e+07
# 5              5.956584e+07               9.979721e+07
# 6              8.272290e+07               1.292807e+08
# 7              1.294118e+08               1.907181e+08
# 8              1.887176e+08               2.607935e+08
# 9              3.002429e+08               4.109054e+08
# 10             9.712870e+08               5.421610e+08
# 11             7.829401e+08               5.801720e+08
# 12             8.236658e+08               1.729869e+09
# 13             8.122343e+08               1.679519e+09
# 14             1.124835e+09               2.248071e+09
# 15             1.873490e+09               1.767385e+09
# 16             4.424479e+09               4.194998e+09
# 17             7.995833e+09               7.411307e+09
# 18             1.012265e+10               8.928549e+09
# 19             9.519222e+09               8.055741e+09
#
#     Waste_silver_PV_ICE_base  Waste_copper_PV_ICE_base  \
# 0               1.903224e+05              2.848183e+03
# 1               1.392646e+05              2.169933e+03
# 2               1.590017e+05              2.609763e+03
# 3               1.558401e+05              2.828400e+03
# 4               2.210346e+05              4.625451e+03
# 5               1.985433e+05              7.251887e+03
# 6               2.979944e+05              1.239959e+04
# 7               4.886206e+05              2.206772e+04
# 8               7.523668e+05              3.646577e+04
# 9               1.188847e+06              5.977646e+04
# 10              8.669476e+06              5.191413e+05
# 11              6.273556e+06              3.885719e+05
# 12              1.644644e+06              7.743406e+04
# 13              1.654403e+06              8.811729e+04
# 14              2.274499e+06              1.340193e+05
# 15              2.414865e+06              2.297470e+05
# 16              4.456339e+06              4.923753e+05
# 17              1.129163e+07              1.148255e+06
# 18              1.107252e+07              1.382319e+06
# 19              1.288704e+07              1.580862e+06
#
#     Waste_aluminium_frames_PV_ICE_base  Waste_Module_PV_ICE_base  \
# 0                         3.797870e+06              2.204195e+08
# 1                         2.823082e+06              1.655405e+08
# 2                         3.015525e+06              1.931714e+08
# 3                         2.960336e+06              1.912092e+08
# 4                         4.447433e+06              2.693325e+08
# 5                         6.229870e+06              3.315974e+08
# 6                         9.677156e+06              4.439823e+08
# 7                         1.628803e+07              6.738573e+08
# 8                         2.571493e+07              9.520297e+08
# 9                         4.122395e+07              1.507242e+09
# 10                        2.973426e+08              3.639958e+09
# 11                        2.190589e+08              3.177666e+09
# 12                        6.319147e+07              5.236896e+09
# 13                        6.634735e+07              5.119685e+09
# 14                        9.566111e+07              6.941951e+09
# 15                        1.607333e+08              7.608507e+09
# 16                        3.555811e+08              1.796001e+10
# 17                        7.531884e+08              3.234554e+10
# 18                        7.971335e+08              3.972157e+10
# 19                        8.515391e+08              3.688194e+10
#
#     Waste_glass_PV_ICE_high  Waste_silicon_PV_ICE_high  \
# 0              3.557465e+07               7.064407e+07
# 1              2.708324e+07               5.272248e+07
# 2              3.215794e+07               6.125064e+07
# 3              3.246804e+07               6.001756e+07
# 4              4.681363e+07               8.317952e+07
# 5              5.956584e+07               9.979721e+07
# 6              8.272290e+07               1.292807e+08
# 7              1.294118e+08               1.907181e+08
# 8              1.887176e+08               2.607935e+08
# 9              3.002429e+08               4.109054e+08
# 10             9.712870e+08               5.421610e+08
# 11             7.829401e+08               5.801720e+08
# 12             8.236658e+08               1.729869e+09
# 13             8.122343e+08               1.679519e+09
# 14             1.124835e+09               2.248071e+09
# 15             1.873490e+09               1.767385e+09
# 16             4.424479e+09               4.194998e+09
# 17             7.995833e+09               7.411307e+09
# 18             1.012265e+10               8.928549e+09
# 19             9.519222e+09               8.055741e+09
#
#     Waste_silver_PV_ICE_high  Waste_copper_PV_ICE_high  ...  \
# 0               1.903224e+05              2.848183e+03  ...
# 1               1.392646e+05              2.169933e+03  ...
# 2               1.590017e+05              2.609763e+03  ...
# 3               1.558401e+05              2.828400e+03  ...
# 4               2.210346e+05              4.625451e+03  ...
# 5               1.985433e+05              7.251887e+03  ...
# 6               2.979944e+05              1.239959e+04  ...
# 7               4.886206e+05              2.206772e+04  ...
# 8               7.523668e+05              3.646577e+04  ...
# 9               1.188847e+06              5.977646e+04  ...
# 10              8.669476e+06              5.191413e+05  ...
# 11              6.273556e+06              3.885719e+05  ...
# 12              1.644644e+06              7.743406e+04  ...
# 13              1.654403e+06              8.811729e+04  ...
# 14              2.274499e+06              1.340193e+05  ...
# 15              2.414865e+06              2.297470e+05  ...
# 16              4.456339e+06              4.923753e+05  ...
# 17              1.129163e+07              1.148255e+06  ...
# 18              1.107252e+07              1.382319e+06  ...
# 19              1.288704e+07              1.580862e+06  ...
#
#     Waste_silver_Irena_RL_base  Waste_copper_Irena_RL_base  \
# 0                 0.000000e+00                    0.000000
# 1                 1.008385e-01                    0.006160
# 2                 4.261066e+00                    0.260495
# 3                 4.017959e+01                    2.462628
# 4                 2.045301e+02                   12.580665
# 5                 7.384826e+02                   45.616871
# 6                 2.138385e+03                  132.722250
# 7                 5.307093e+03                  331.248780
# 8                 1.174804e+04                  738.496774
# 9                 2.380407e+04                 1510.149065
# 10                4.494534e+04                 2884.826893
# 11                8.010870e+04                 5216.655640
# 12                1.360825e+05                 9017.821351
# 13                2.219036e+05                15011.080777
# 14                3.492110e+05                24192.335385
# 15                5.325085e+05                37909.286827
# 16                7.892351e+05                57958.731976
# 17                1.139494e+06                86705.485873
# 18                1.605300e+06               127248.593433
# 19                2.209361e+06               183716.644821
#
#     Waste_aluminium_frames_Irena_RL_base  Waste_Module_Irena_RL_base  \
# 0                           0.000000e+00                0.000000e+00
# 1                           3.452903e+00                2.698380e+01
# 2                           1.459467e+02                1.140876e+03
# 3                           1.377322e+03                1.077943e+04
# 4                           7.011592e+03                5.501037e+04
# 5                           2.529173e+04                1.991646e+05
# 6                           7.311216e+04                5.784027e+05
# 7                           1.811314e+05                1.440566e+06
# 8                           4.005756e+05                3.204325e+06
# 9                           8.121137e+05                6.536534e+06
# 10                          1.537328e+06                1.245437e+07
# 11                          2.753421e+06                2.245949e+07
# 12                          4.711651e+06                3.871124e+07
# 13                          7.758910e+06                6.423710e+07
# 14                          1.236155e+07                1.031778e+08
# 15                          1.913242e+07                1.610857e+08
# 16                          2.886041e+07                2.452814e+08
# 17                          4.254152e+07                3.652725e+08
# 18                          6.141906e+07                5.333264e+08
# 19                          8.706153e+07                7.655048e+08
#
#     Waste_glass_Irena_RL_high  Waste_silicon_Irena_RL_high  \
# 0                0.000000e+00                 0.000000e+00
# 1                8.969129e+00                 9.628666e-01
# 2                3.792685e+02                 4.070139e+01
# 3                3.585469e+03                 3.842814e+02
# 4                1.831685e+04                 1.959632e+03
# 5                6.641599e+04                 7.090471e+03
# 6                1.932373e+05                 2.058078e+04
# 7                4.822824e+05                 5.123076e+04
# 8                1.075216e+06                 1.138843e+05
# 9                2.198705e+06                 2.321339e+05
# 10               4.200171e+06                 4.418569e+05
# 11               7.595202e+06                 7.957963e+05
# 12               1.312952e+07                 1.369349e+06
# 13               2.185542e+07                 2.267308e+06
# 14               3.522289e+07                 3.631043e+06
# 15               5.519412e+07                 5.645880e+06
# 16               8.438515e+07                 8.547926e+06
# 17               1.262391e+08                 1.262946e+07
# 18               1.852679e+08                 1.824366e+07
# 19               2.674835e+08                 2.581433e+07
#
#     Waste_silver_Irena_RL_high  Waste_copper_Irena_RL_high  \
# 0                 0.000000e+00                    0.000000
# 1                 1.008385e-01                    0.006160
# 2                 4.261066e+00                    0.260495
# 3                 4.017959e+01                    2.462628
# 4                 2.045301e+02                   12.580665
# 5                 7.384826e+02                   45.616871
# 6                 2.138385e+03                  132.722250
# 7                 5.307093e+03                  331.248780
# 8                 1.174804e+04                  738.496774
# 9                 2.380407e+04                 1510.149065
# 10                4.494534e+04                 2884.826893
# 11                8.010870e+04                 5216.655640
# 12                1.360825e+05                 9017.821351
# 13                2.219036e+05                15011.080777
# 14                3.492110e+05                24192.335385
# 15                5.325085e+05                37909.286827
# 16                7.892351e+05                57958.731976
# 17                1.139494e+06                86705.485873
# 18                1.605300e+06               127248.593433
# 19                2.209361e+06               183716.644821
#
#     Waste_aluminium_frames_Irena_RL_high  Waste_Module_Irena_RL_high
# 0                           0.000000e+00                0.000000e+00
# 1                           3.452903e+00                2.698380e+01
# 2                           1.459467e+02                1.140876e+03
# 3                           1.377322e+03                1.077943e+04
# 4                           7.011592e+03                5.501037e+04
# 5                           2.529173e+04                1.991646e+05
# 6                           7.311216e+04                5.784027e+05
# 7                           1.811314e+05                1.440566e+06
# 8                           4.005756e+05                3.204325e+06
# 9                           8.121137e+05                6.536534e+06
# 10                          1.537328e+06                1.245437e+07
# 11                          2.753421e+06                2.245949e+07
# 12                          4.711651e+06                3.871124e+07
# 13                          7.758910e+06                6.423710e+07
# 14                          1.236155e+07                1.031778e+08
# 15                          1.913242e+07                1.610857e+08
# 16                          2.886041e+07                2.452814e+08
# 17                          4.254152e+07                3.652725e+08
# 18                          6.141906e+07                5.333264e+08
# 19                          8.706153e+07                7.655048e+08
#
# [20 rows x 48 columns]

# %%
keyword='mat_Total_EOL_Landfilled'
materials = ['glass', 'silicon', 'silver', 'copper', 'aluminium_frames']

# Loop over objects
for kk in range(0, len(objects)):
    obj = objects[kk]

    # Loop over Scenarios
    for jj in range(0, len(scenarios)):
        case = scenarios[jj]
        
        for ii in range (0, len(materials)):    
            material = materials[ii]
            foo = obj.scenario[case].material[material].materialdata[keyword].copy()
            foo = foo.to_frame(name=material)
            USyearly["Waste_EOL_"+material+'_'+obj.name+'_'+case] = foo[material]

        filter_col = [col for col in USyearly if (col.startswith('Waste') and col.endswith(obj.name+'_'+case)) ]
        USyearly['Waste_EOL_Module_'+obj.name+'_'+case] = USyearly[filter_col].sum(axis=1)

# Converting to grams to Tons. 
USyearly.head(20)
# Out:
#     Waste_glass_PV_ICE_base  Waste_silicon_PV_ICE_base  \
# 0              3.557465e+07               7.064407e+07
# 1              2.708324e+07               5.272248e+07
# 2              3.215794e+07               6.125064e+07
# 3              3.246804e+07               6.001756e+07
# 4              4.681363e+07               8.317952e+07
# 5              5.956584e+07               9.979721e+07
# 6              8.272290e+07               1.292807e+08
# 7              1.294118e+08               1.907181e+08
# 8              1.887176e+08               2.607935e+08
# 9              3.002429e+08               4.109054e+08
# 10             9.712870e+08               5.421610e+08
# 11             7.829401e+08               5.801720e+08
# 12             8.236658e+08               1.729869e+09
# 13             8.122343e+08               1.679519e+09
# 14             1.124835e+09               2.248071e+09
# 15             1.873490e+09               1.767385e+09
# 16             4.424479e+09               4.194998e+09
# 17             7.995833e+09               7.411307e+09
# 18             1.012265e+10               8.928549e+09
# 19             9.519222e+09               8.055741e+09
#
#     Waste_silver_PV_ICE_base  Waste_copper_PV_ICE_base  \
# 0               1.903224e+05              2.848183e+03
# 1               1.392646e+05              2.169933e+03
# 2               1.590017e+05              2.609763e+03
# 3               1.558401e+05              2.828400e+03
# 4               2.210346e+05              4.625451e+03
# 5               1.985433e+05              7.251887e+03
# 6               2.979944e+05              1.239959e+04
# 7               4.886206e+05              2.206772e+04
# 8               7.523668e+05              3.646577e+04
# 9               1.188847e+06              5.977646e+04
# 10              8.669476e+06              5.191413e+05
# 11              6.273556e+06              3.885719e+05
# 12              1.644644e+06              7.743406e+04
# 13              1.654403e+06              8.811729e+04
# 14              2.274499e+06              1.340193e+05
# 15              2.414865e+06              2.297470e+05
# 16              4.456339e+06              4.923753e+05
# 17              1.129163e+07              1.148255e+06
# 18              1.107252e+07              1.382319e+06
# 19              1.288704e+07              1.580862e+06
#
#     Waste_aluminium_frames_PV_ICE_base  Waste_Module_PV_ICE_base  \
# 0                         3.797870e+06              2.204195e+08
# 1                         2.823082e+06              1.655405e+08
# 2                         3.015525e+06              1.931714e+08
# 3                         2.960336e+06              1.912092e+08
# 4                         4.447433e+06              2.693325e+08
# 5                         6.229870e+06              3.315974e+08
# 6                         9.677156e+06              4.439823e+08
# 7                         1.628803e+07              6.738573e+08
# 8                         2.571493e+07              9.520297e+08
# 9                         4.122395e+07              1.507242e+09
# 10                        2.973426e+08              3.639958e+09
# 11                        2.190589e+08              3.177666e+09
# 12                        6.319147e+07              5.236896e+09
# 13                        6.634735e+07              5.119685e+09
# 14                        9.566111e+07              6.941951e+09
# 15                        1.607333e+08              7.608507e+09
# 16                        3.555811e+08              1.796001e+10
# 17                        7.531884e+08              3.234554e+10
# 18                        7.971335e+08              3.972157e+10
# 19                        8.515391e+08              3.688194e+10
#
#     Waste_glass_PV_ICE_high  Waste_silicon_PV_ICE_high  \
# 0              3.557465e+07               7.064407e+07
# 1              2.708324e+07               5.272248e+07
# 2              3.215794e+07               6.125064e+07
# 3              3.246804e+07               6.001756e+07
# 4              4.681363e+07               8.317952e+07
# 5              5.956584e+07               9.979721e+07
# 6              8.272290e+07               1.292807e+08
# 7              1.294118e+08               1.907181e+08
# 8              1.887176e+08               2.607935e+08
# 9              3.002429e+08               4.109054e+08
# 10             9.712870e+08               5.421610e+08
# 11             7.829401e+08               5.801720e+08
# 12             8.236658e+08               1.729869e+09
# 13             8.122343e+08               1.679519e+09
# 14             1.124835e+09               2.248071e+09
# 15             1.873490e+09               1.767385e+09
# 16             4.424479e+09               4.194998e+09
# 17             7.995833e+09               7.411307e+09
# 18             1.012265e+10               8.928549e+09
# 19             9.519222e+09               8.055741e+09
#
#     Waste_silver_PV_ICE_high  Waste_copper_PV_ICE_high  ...  \
# 0               1.903224e+05              2.848183e+03  ...
# 1               1.392646e+05              2.169933e+03  ...
# 2               1.590017e+05              2.609763e+03  ...
# 3               1.558401e+05              2.828400e+03  ...
# 4               2.210346e+05              4.625451e+03  ...
# 5               1.985433e+05              7.251887e+03  ...
# 6               2.979944e+05              1.239959e+04  ...
# 7               4.886206e+05              2.206772e+04  ...
# 8               7.523668e+05              3.646577e+04  ...
# 9               1.188847e+06              5.977646e+04  ...
# 10              8.669476e+06              5.191413e+05  ...
# 11              6.273556e+06              3.885719e+05  ...
# 12              1.644644e+06              7.743406e+04  ...
# 13              1.654403e+06              8.811729e+04  ...
# 14              2.274499e+06              1.340193e+05  ...
# 15              2.414865e+06              2.297470e+05  ...
# 16              4.456339e+06              4.923753e+05  ...
# 17              1.129163e+07              1.148255e+06  ...
# 18              1.107252e+07              1.382319e+06  ...
# 19              1.288704e+07              1.580862e+06  ...
#
#     Waste_EOL_silver_Irena_RL_base  Waste_EOL_copper_Irena_RL_base  \
# 0                     0.000000e+00                        0.000000
# 1                     1.008385e-01                        0.006160
# 2                     4.261066e+00                        0.260495
# 3                     4.017959e+01                        2.462628
# 4                     2.045301e+02                       12.580665
# 5                     7.384826e+02                       45.616871
# 6                     2.138385e+03                      132.722250
# 7                     5.307093e+03                      331.248780
# 8                     1.174804e+04                      738.496774
# 9                     2.380407e+04                     1510.149065
# 10                    4.494534e+04                     2884.826893
# 11                    8.010870e+04                     5216.655640
# 12                    1.360825e+05                     9017.821351
# 13                    2.219036e+05                    15011.080777
# 14                    3.492110e+05                    24192.335385
# 15                    5.325085e+05                    37909.286827
# 16                    7.892351e+05                    57958.731976
# 17                    1.139494e+06                    86705.485873
# 18                    1.605300e+06                   127248.593433
# 19                    2.209361e+06                   183716.644821
#
#     Waste_EOL_aluminium_frames_Irena_RL_base  Waste_EOL_Module_Irena_RL_base  \
# 0                               0.000000e+00                    0.000000e+00
# 1                               3.452903e+00                    5.396759e+01
# 2                               1.459467e+02                    2.281752e+03
# 3                               1.377322e+03                    2.155886e+04
# 4                               7.011592e+03                    1.100207e+05
# 5                               2.529173e+04                    3.983292e+05
# 6                               7.311216e+04                    1.156805e+06
# 7                               1.811314e+05                    2.881132e+06
# 8                               4.005756e+05                    6.408650e+06
# 9                               8.121137e+05                    1.307307e+07
# 10                              1.537328e+06                    2.490874e+07
# 11                              2.753421e+06                    4.491898e+07
# 12                              4.711651e+06                    7.742248e+07
# 13                              7.758910e+06                    1.284742e+08
# 14                              1.236155e+07                    2.063555e+08
# 15                              1.913242e+07                    3.221713e+08
# 16                              2.886041e+07                    4.905627e+08
# 17                              4.254152e+07                    7.305449e+08
# 18                              6.141906e+07                    1.066653e+09
# 19                              8.706153e+07                    1.531010e+09
#
#     Waste_EOL_glass_Irena_RL_high  Waste_EOL_silicon_Irena_RL_high  \
# 0                    0.000000e+00                     0.000000e+00
# 1                    8.969129e+00                     9.628666e-01
# 2                    3.792685e+02                     4.070139e+01
# 3                    3.585469e+03                     3.842814e+02
# 4                    1.831685e+04                     1.959632e+03
# 5                    6.641599e+04                     7.090471e+03
# 6                    1.932373e+05                     2.058078e+04
# 7                    4.822824e+05                     5.123076e+04
# 8                    1.075216e+06                     1.138843e+05
# 9                    2.198705e+06                     2.321339e+05
# 10                   4.200171e+06                     4.418569e+05
# 11                   7.595202e+06                     7.957963e+05
# 12                   1.312952e+07                     1.369349e+06
# 13                   2.185542e+07                     2.267308e+06
# 14                   3.522289e+07                     3.631043e+06
# 15                   5.519412e+07                     5.645880e+06
# 16                   8.438515e+07                     8.547926e+06
# 17                   1.262391e+08                     1.262946e+07
# 18                   1.852679e+08                     1.824366e+07
# 19                   2.674835e+08                     2.581433e+07
#
#     Waste_EOL_silver_Irena_RL_high  Waste_EOL_copper_Irena_RL_high  \
# 0                     0.000000e+00                        0.000000
# 1                     1.008385e-01                        0.006160
# 2                     4.261066e+00                        0.260495
# 3                     4.017959e+01                        2.462628
# 4                     2.045301e+02                       12.580665
# 5                     7.384826e+02                       45.616871
# 6                     2.138385e+03                      132.722250
# 7                     5.307093e+03                      331.248780
# 8                     1.174804e+04                      738.496774
# 9                     2.380407e+04                     1510.149065
# 10                    4.494534e+04                     2884.826893
# 11                    8.010870e+04                     5216.655640
# 12                    1.360825e+05                     9017.821351
# 13                    2.219036e+05                    15011.080777
# 14                    3.492110e+05                    24192.335385
# 15                    5.325085e+05                    37909.286827
# 16                    7.892351e+05                    57958.731976
# 17                    1.139494e+06                    86705.485873
# 18                    1.605300e+06                   127248.593433
# 19                    2.209361e+06                   183716.644821
#
#     Waste_EOL_aluminium_frames_Irena_RL_high  Waste_EOL_Module_Irena_RL_high
# 0                               0.000000e+00                    0.000000e+00
# 1                               3.452903e+00                    5.396759e+01
# 2                               1.459467e+02                    2.281752e+03
# 3                               1.377322e+03                    2.155886e+04
# 4                               7.011592e+03                    1.100207e+05
# 5                               2.529173e+04                    3.983292e+05
# 6                               7.311216e+04                    1.156805e+06
# 7                               1.811314e+05                    2.881132e+06
# 8                               4.005756e+05                    6.408650e+06
# 9                               8.121137e+05                    1.307307e+07
# 10                              1.537328e+06                    2.490874e+07
# 11                              2.753421e+06                    4.491898e+07
# 12                              4.711651e+06                    7.742248e+07
# 13                              7.758910e+06                    1.284742e+08
# 14                              1.236155e+07                    2.063555e+08
# 15                              1.913242e+07                    3.221713e+08
# 16                              2.886041e+07                    4.905627e+08
# 17                              4.254152e+07                    7.305449e+08
# 18                              6.141906e+07                    1.066653e+09
# 19                              8.706153e+07                    1.531010e+09
#
# [20 rows x 96 columns]

# %%
keyword='mat_Total_MFG_Landfilled'
materials = ['glass', 'silicon', 'silver', 'copper', 'aluminium_frames']

# Loop over objects
for kk in range(0, len(objects)):
    obj = objects[kk]

    # Loop over Scenarios
    for jj in range(0, len(scenarios)):
        case = scenarios[jj]
        
        for ii in range (0, len(materials)):    
            material = materials[ii]
            foo = obj.scenario[case].material[material].materialdata[keyword].copy()
            foo = foo.to_frame(name=material)
            USyearly["Waste_MFG_"+material+'_'+obj.name+'_'+case] = foo[material]

        filter_col = [col for col in USyearly if (col.startswith('Waste') and col.endswith(obj.name+'_'+case)) ]
        USyearly['Waste_MFG_Module_'+obj.name+'_'+case] = USyearly[filter_col].sum(axis=1)

# Converting to grams to Tons. 
USyearly.head(20)
# Out:
#     Waste_glass_PV_ICE_base  Waste_silicon_PV_ICE_base  \
# 0              3.557465e+07               7.064407e+07
# 1              2.708324e+07               5.272248e+07
# 2              3.215794e+07               6.125064e+07
# 3              3.246804e+07               6.001756e+07
# 4              4.681363e+07               8.317952e+07
# 5              5.956584e+07               9.979721e+07
# 6              8.272290e+07               1.292807e+08
# 7              1.294118e+08               1.907181e+08
# 8              1.887176e+08               2.607935e+08
# 9              3.002429e+08               4.109054e+08
# 10             9.712870e+08               5.421610e+08
# 11             7.829401e+08               5.801720e+08
# 12             8.236658e+08               1.729869e+09
# 13             8.122343e+08               1.679519e+09
# 14             1.124835e+09               2.248071e+09
# 15             1.873490e+09               1.767385e+09
# 16             4.424479e+09               4.194998e+09
# 17             7.995833e+09               7.411307e+09
# 18             1.012265e+10               8.928549e+09
# 19             9.519222e+09               8.055741e+09
#
#     Waste_silver_PV_ICE_base  Waste_copper_PV_ICE_base  \
# 0               1.903224e+05              2.848183e+03
# 1               1.392646e+05              2.169933e+03
# 2               1.590017e+05              2.609763e+03
# 3               1.558401e+05              2.828400e+03
# 4               2.210346e+05              4.625451e+03
# 5               1.985433e+05              7.251887e+03
# 6               2.979944e+05              1.239959e+04
# 7               4.886206e+05              2.206772e+04
# 8               7.523668e+05              3.646577e+04
# 9               1.188847e+06              5.977646e+04
# 10              8.669476e+06              5.191413e+05
# 11              6.273556e+06              3.885719e+05
# 12              1.644644e+06              7.743406e+04
# 13              1.654403e+06              8.811729e+04
# 14              2.274499e+06              1.340193e+05
# 15              2.414865e+06              2.297470e+05
# 16              4.456339e+06              4.923753e+05
# 17              1.129163e+07              1.148255e+06
# 18              1.107252e+07              1.382319e+06
# 19              1.288704e+07              1.580862e+06
#
#     Waste_aluminium_frames_PV_ICE_base  Waste_Module_PV_ICE_base  \
# 0                         3.797870e+06              2.204195e+08
# 1                         2.823082e+06              1.655405e+08
# 2                         3.015525e+06              1.931714e+08
# 3                         2.960336e+06              1.912092e+08
# 4                         4.447433e+06              2.693325e+08
# 5                         6.229870e+06              3.315974e+08
# 6                         9.677156e+06              4.439823e+08
# 7                         1.628803e+07              6.738573e+08
# 8                         2.571493e+07              9.520297e+08
# 9                         4.122395e+07              1.507242e+09
# 10                        2.973426e+08              3.639958e+09
# 11                        2.190589e+08              3.177666e+09
# 12                        6.319147e+07              5.236896e+09
# 13                        6.634735e+07              5.119685e+09
# 14                        9.566111e+07              6.941951e+09
# 15                        1.607333e+08              7.608507e+09
# 16                        3.555811e+08              1.796001e+10
# 17                        7.531884e+08              3.234554e+10
# 18                        7.971335e+08              3.972157e+10
# 19                        8.515391e+08              3.688194e+10
#
#     Waste_glass_PV_ICE_high  Waste_silicon_PV_ICE_high  \
# 0              3.557465e+07               7.064407e+07
# 1              2.708324e+07               5.272248e+07
# 2              3.215794e+07               6.125064e+07
# 3              3.246804e+07               6.001756e+07
# 4              4.681363e+07               8.317952e+07
# 5              5.956584e+07               9.979721e+07
# 6              8.272290e+07               1.292807e+08
# 7              1.294118e+08               1.907181e+08
# 8              1.887176e+08               2.607935e+08
# 9              3.002429e+08               4.109054e+08
# 10             9.712870e+08               5.421610e+08
# 11             7.829401e+08               5.801720e+08
# 12             8.236658e+08               1.729869e+09
# 13             8.122343e+08               1.679519e+09
# 14             1.124835e+09               2.248071e+09
# 15             1.873490e+09               1.767385e+09
# 16             4.424479e+09               4.194998e+09
# 17             7.995833e+09               7.411307e+09
# 18             1.012265e+10               8.928549e+09
# 19             9.519222e+09               8.055741e+09
#
#     Waste_silver_PV_ICE_high  Waste_copper_PV_ICE_high  ...  \
# 0               1.903224e+05              2.848183e+03  ...
# 1               1.392646e+05              2.169933e+03  ...
# 2               1.590017e+05              2.609763e+03  ...
# 3               1.558401e+05              2.828400e+03  ...
# 4               2.210346e+05              4.625451e+03  ...
# 5               1.985433e+05              7.251887e+03  ...
# 6               2.979944e+05              1.239959e+04  ...
# 7               4.886206e+05              2.206772e+04  ...
# 8               7.523668e+05              3.646577e+04  ...
# 9               1.188847e+06              5.977646e+04  ...
# 10              8.669476e+06              5.191413e+05  ...
# 11              6.273556e+06              3.885719e+05  ...
# 12              1.644644e+06              7.743406e+04  ...
# 13              1.654403e+06              8.811729e+04  ...
# 14              2.274499e+06              1.340193e+05  ...
# 15              2.414865e+06              2.297470e+05  ...
# 16              4.456339e+06              4.923753e+05  ...
# 17              1.129163e+07              1.148255e+06  ...
# 18              1.107252e+07              1.382319e+06  ...
# 19              1.288704e+07              1.580862e+06  ...
#
#     Waste_MFG_silver_Irena_RL_base  Waste_MFG_copper_Irena_RL_base  \
# 0                     0.000000e+00                    0.000000e+00
# 1                     0.000000e+00                    0.000000e+00
# 2                     0.000000e+00                    0.000000e+00
# 3                     9.313226e-10                    0.000000e+00
# 4                     0.000000e+00                    0.000000e+00
# 5                     0.000000e+00                    1.164153e-10
# 6                     0.000000e+00                    0.000000e+00
# 7                     0.000000e+00                    0.000000e+00
# 8                     0.000000e+00                    0.000000e+00
# 9                     0.000000e+00                    0.000000e+00
# 10                    0.000000e+00                    0.000000e+00
# 11                    0.000000e+00                    0.000000e+00
# 12                    0.000000e+00                    0.000000e+00
# 13                    0.000000e+00                    0.000000e+00
# 14                    0.000000e+00                    0.000000e+00
# 15                    0.000000e+00                    0.000000e+00
# 16                   -1.490116e-08                   -7.450581e-09
# 17                    0.000000e+00                    0.000000e+00
# 18                    0.000000e+00                    0.000000e+00
# 19                    0.000000e+00                    0.000000e+00
#
#     Waste_MFG_aluminium_frames_Irena_RL_base  Waste_MFG_Module_Irena_RL_base  \
# 0                               0.000000e+00                    0.000000e+00
# 1                               0.000000e+00                    1.079352e+02
# 2                               0.000000e+00                    4.563505e+03
# 3                               2.980232e-08                    4.311772e+04
# 4                               0.000000e+00                    2.200415e+05
# 5                               0.000000e+00                    7.966583e+05
# 6                               0.000000e+00                    2.313611e+06
# 7                               0.000000e+00                    5.762263e+06
# 8                               0.000000e+00                    1.281730e+07
# 9                               0.000000e+00                    2.614614e+07
# 10                              0.000000e+00                    4.981749e+07
# 11                              2.384186e-07                    8.983796e+07
# 12                              0.000000e+00                    1.548450e+08
# 13                              0.000000e+00                    2.569484e+08
# 14                              0.000000e+00                    4.127111e+08
# 15                              0.000000e+00                    6.443427e+08
# 16                              3.814697e-06                    9.811255e+08
# 17                              0.000000e+00                    1.461090e+09
# 18                              0.000000e+00                    2.133305e+09
# 19                              0.000000e+00                    3.062019e+09
#
#     Waste_MFG_glass_Irena_RL_high  Waste_MFG_silicon_Irena_RL_high  \
# 0                    0.000000e+00                     0.000000e+00
# 1                    0.000000e+00                     0.000000e+00
# 2                    1.192093e-07                     0.000000e+00
# 3                    0.000000e+00                     0.000000e+00
# 4                    0.000000e+00                     0.000000e+00
# 5                    0.000000e+00                     0.000000e+00
# 6                    0.000000e+00                     0.000000e+00
# 7                    0.000000e+00                     0.000000e+00
# 8                    0.000000e+00                     0.000000e+00
# 9                    0.000000e+00                     0.000000e+00
# 10                   0.000000e+00                    -5.960464e-08
# 11                   9.536743e-07                     0.000000e+00
# 12                   0.000000e+00                     0.000000e+00
# 13                   0.000000e+00                     0.000000e+00
# 14                   0.000000e+00                     0.000000e+00
# 15                   0.000000e+00                     0.000000e+00
# 16                   1.525879e-05                     0.000000e+00
# 17                   0.000000e+00                     0.000000e+00
# 18                   0.000000e+00                     0.000000e+00
# 19                   0.000000e+00                     0.000000e+00
#
#     Waste_MFG_silver_Irena_RL_high  Waste_MFG_copper_Irena_RL_high  \
# 0                     0.000000e+00                    0.000000e+00
# 1                     0.000000e+00                    0.000000e+00
# 2                     0.000000e+00                    0.000000e+00
# 3                     9.313226e-10                    0.000000e+00
# 4                     0.000000e+00                    0.000000e+00
# 5                     0.000000e+00                    1.164153e-10
# 6                     0.000000e+00                    0.000000e+00
# 7                     0.000000e+00                    0.000000e+00
# 8                     0.000000e+00                    0.000000e+00
# 9                     0.000000e+00                    0.000000e+00
# 10                    0.000000e+00                    0.000000e+00
# 11                    0.000000e+00                    0.000000e+00
# 12                    0.000000e+00                    0.000000e+00
# 13                    0.000000e+00                    0.000000e+00
# 14                    0.000000e+00                    0.000000e+00
# 15                    0.000000e+00                    0.000000e+00
# 16                   -1.490116e-08                   -7.450581e-09
# 17                    0.000000e+00                    0.000000e+00
# 18                    0.000000e+00                    0.000000e+00
# 19                    0.000000e+00                    0.000000e+00
#
#     Waste_MFG_aluminium_frames_Irena_RL_high  Waste_MFG_Module_Irena_RL_high
# 0                               0.000000e+00                    0.000000e+00
# 1                               0.000000e+00                    1.079352e+02
# 2                               0.000000e+00                    4.563505e+03
# 3                               2.980232e-08                    4.311772e+04
# 4                               0.000000e+00                    2.200415e+05
# 5                               0.000000e+00                    7.966583e+05
# 6                               0.000000e+00                    2.313611e+06
# 7                               0.000000e+00                    5.762263e+06
# 8                               0.000000e+00                    1.281730e+07
# 9                               0.000000e+00                    2.614614e+07
# 10                              0.000000e+00                    4.981749e+07
# 11                              2.384186e-07                    8.983796e+07
# 12                              0.000000e+00                    1.548450e+08
# 13                              0.000000e+00                    2.569484e+08
# 14                              0.000000e+00                    4.127111e+08
# 15                              0.000000e+00                    6.443427e+08
# 16                              3.814697e-06                    9.811255e+08
# 17                              0.000000e+00                    1.461090e+09
# 18                              0.000000e+00                    2.133305e+09
# 19                              0.000000e+00                    3.062019e+09
#
# [20 rows x 144 columns]

# %%
keyword='mat_Virgin_Stock'
materials = ['glass', 'silicon', 'silver', 'copper', 'aluminium_frames']

# Loop over objects
for kk in range(0, len(objects)):
    obj = objects[kk]

    # Loop over Scenarios
    for jj in range(0, len(scenarios)):
        case = scenarios[jj]
        
        for ii in range (0, len(materials)):    
            material = materials[ii]
            foo = obj.scenario[case].material[material].materialdata[keyword].copy()
            foo = foo.to_frame(name=material)
            USyearly["VirginStock_"+material+'_'+obj.name+'_'+case] = foo[material]

        filter_col = [col for col in USyearly if (col.startswith('VirginStock_') and col.endswith(obj.name+'_'+case)) ]
        USyearly['VirginStock_Module_'+obj.name+'_'+case] = USyearly[filter_col].sum(axis=1)

# %% [markdown]
# ### Converting to grams to METRIC Tons.

# %%
USyearly = USyearly/1000000  # This is the ratio for Metric tonnes
#907185 -- this is for US tons

# %%
UScum = USyearly.copy()
UScum = UScum.cumsum()
UScum.head()
# Out:
#    Waste_glass_PV_ICE_base  Waste_silicon_PV_ICE_base  \
# 0                35.574651                  70.644070
# 1                62.657891                 123.366547
# 2                94.815832                 184.617192
# 3               127.283871                 244.634747
# 4               174.097497                 327.814264
#
#    Waste_silver_PV_ICE_base  Waste_copper_PV_ICE_base  \
# 0                  0.190322                  0.002848
# 1                  0.329587                  0.005018
# 2                  0.488589                  0.007628
# 3                  0.644429                  0.010456
# 4                  0.865463                  0.015082
#
#    Waste_aluminium_frames_PV_ICE_base  Waste_Module_PV_ICE_base  \
# 0                            3.797870                220.419522
# 1                            6.620951                385.959989
# 2                            9.636476                579.131434
# 3                           12.596813                770.340632
# 4                           17.044245               1039.673103
#
#    Waste_glass_PV_ICE_high  Waste_silicon_PV_ICE_high  \
# 0                35.574651                  70.644070
# 1                62.657891                 123.366547
# 2                94.815832                 184.617192
# 3               127.283871                 244.634747
# 4               174.097497                 327.814264
#
#    Waste_silver_PV_ICE_high  Waste_copper_PV_ICE_high  ...  \
# 0                  0.190322                  0.002848  ...
# 1                  0.329587                  0.005018  ...
# 2                  0.488589                  0.007628  ...
# 3                  0.644429                  0.010456  ...
# 4                  0.865463                  0.015082  ...
#
#    VirginStock_silver_Irena_RL_base  VirginStock_copper_Irena_RL_base  \
# 0                          8.800000                          0.537600
# 1                         15.237861                          0.946839
# 2                         22.559618                          1.431931
# 3                         29.569970                          1.916883
# 4                         39.043456                          2.602472
#
#    VirginStock_aluminium_frames_Irena_RL_base  \
# 0                                  309.118541
# 1                                  538.814426
# 2                                  782.443304
# 3                                 1011.602001
# 4                                 1328.469742
#
#    VirginStock_Module_Irena_RL_base  VirginStock_glass_Irena_RL_high  \
# 0                       1203.298284                       800.000000
# 1                       2112.146469                      1408.986877
# 2                       3158.998914                      2130.850231
# 3                       4189.338187                      2852.504135
# 4                       5636.297721                      3872.725681
#
#    VirginStock_silicon_Irena_RL_high  VirginStock_silver_Irena_RL_high  \
# 0                          84.842143                          8.800000
# 1                         148.160466                         15.237861
# 2                         221.713830                         22.559618
# 3                         293.745199                         29.569970
# 4                         393.456370                         39.043456
#
#    VirginStock_copper_Irena_RL_high  \
# 0                          0.537600
# 1                          0.946839
# 2                          1.431931
# 3                          1.916883
# 4                          2.602472
#
#    VirginStock_aluminium_frames_Irena_RL_high  \
# 0                                  309.118541
# 1                                  538.814426
# 2                                  782.443304
# 3                                 1011.602001
# 4                                 1328.469742
#
#    VirginStock_Module_Irena_RL_high
# 0                       1203.298284
# 1                       2112.146469
# 2                       3158.998914
# 3                       4189.338187
# 4                       5636.297721
#
# [5 rows x 192 columns]

# %% [markdown]
# ### Adding Installed Capacity to US

# %%
keyword='Installed_Capacity_[W]'
materials = ['glass', 'silicon', 'silver', 'copper', 'aluminium_frames']

# Loop over SF Scenarios
for kk in range(0, len(objects)):
    obj = objects[kk]
    
    # Loop over Scenarios
    for jj in range(0, len(scenarios)):
        case = scenarios[jj]
        
        foo = obj.scenario[case].data[keyword]
        foo = foo.to_frame(name=keyword)
        UScum["Capacity_"+obj.name+'_'+case] = foo[keyword]

# %%
UScum.tail(20)
# Out:
#     Waste_glass_PV_ICE_base  Waste_silicon_PV_ICE_base  \
# 36             6.289427e+05              270763.888938
# 37             7.155318e+05              280317.203136
# 38             8.006137e+05              289178.129309
# 39             9.289472e+05              300270.094597
# 40             1.092277e+06              315472.668475
# 41             1.232066e+06              329352.387939
# 42             1.504045e+06              350280.200272
# 43             1.698871e+06              367094.384403
# 44             1.940826e+06              389509.400237
# 45             2.261808e+06              415840.388946
# 46             2.550837e+06              441172.307284
# 47             2.856645e+06              467155.037287
# 48             3.190555e+06              497024.676052
# 49             3.517752e+06              526256.532777
# 50             3.769862e+06              549885.672962
# 51             4.040507e+06              574038.748100
# 52             4.313315e+06              602433.994235
# 53             4.619594e+06              631902.777571
# 54             4.969900e+06              662101.180140
# 55             5.369667e+06              694051.465968
#
#     Waste_silver_PV_ICE_base  Waste_copper_PV_ICE_base  \
# 36                624.715566                227.962163
# 37                705.906541                284.580043
# 38                769.594430                341.952057
# 39                874.478013                430.904330
# 40                990.198870                544.098942
# 41               1065.411372                645.206514
# 42               1228.753265                840.480759
# 43               1328.434546                990.469516
# 44               1450.128934               1176.931360
# 45               1617.491775               1424.468046
# 46               1757.320092               1658.428235
# 47               1903.553515               1910.323559
# 48               2060.645599               2184.071590
# 49               2208.569980               2457.756677
# 50               2313.841199               2676.202683
# 51               2422.154354               2911.674104
# 52               2521.110582               3143.417897
# 53               2627.459932               3405.716133
# 54               2745.660421               3709.424790
# 55               2877.233359               4058.477430
#
#     Waste_aluminium_frames_PV_ICE_base  Waste_Module_PV_ICE_base  \
# 36                        81420.901748              1.963960e+06
# 37                        99014.462955              2.191708e+06
# 38                       115358.020864              2.412523e+06
# 39                       140899.228995              2.742844e+06
# 40                       172294.995554              3.163158e+06
# 41                       195760.128282              3.517777e+06
# 42                       244323.290467              4.201435e+06
# 43                       276451.403982              4.689472e+06
# 44                       315803.817160              5.297533e+06
# 45                       369145.062710              6.099670e+06
# 46                       415095.201417              6.821040e+06
# 47                       463306.173383              7.581841e+06
# 48                       515339.763627              8.414328e+06
# 49                       565148.948161              9.227647e+06
# 50                       601469.613625              9.852414e+06
# 51                       639939.613270              1.051964e+07
# 52                       676800.495210              1.119643e+07
# 53                       717777.751407              1.195062e+07
# 54                       764499.113004              1.280591e+07
# 55                       817589.343479              1.377649e+07
#
#     Waste_glass_PV_ICE_high  Waste_silicon_PV_ICE_high  \
# 36             9.755610e+05               4.641686e+05
# 37             1.104952e+06               4.982012e+05
# 38             1.228999e+06               5.292793e+05
# 39             1.396337e+06               5.624862e+05
# 40             1.599958e+06               6.003082e+05
# 41             1.780647e+06               6.367389e+05
# 42             2.103141e+06               6.850071e+05
# 43             2.350545e+06               7.291439e+05
# 44             2.649076e+06               7.792344e+05
# 45             3.032168e+06               8.333693e+05
# 46             3.343634e+06               8.591200e+05
# 47             3.684834e+06               8.860334e+05
# 48             4.065716e+06               9.134576e+05
# 49             4.466351e+06               9.412951e+05
# 50             4.835206e+06               9.690312e+05
# 51             5.270476e+06               9.991611e+05
# 52             5.764126e+06               1.033199e+06
# 53             6.365228e+06               1.071181e+06
# 54             7.108327e+06               1.120791e+06
# 55             7.990592e+06               1.175561e+06
#
#     Waste_silver_PV_ICE_high  Waste_copper_PV_ICE_high  ...  \
# 36                704.751284                291.614229  ...
# 37                795.170227                356.628126  ...
# 38                867.277324                421.738124  ...
# 39                980.621458                518.608817  ...
# 40               1105.140440                640.295270  ...
# 41               1189.388817                750.591731  ...
# 42               1364.016525                957.920925  ...
# 43               1475.723809               1122.025239  ...
# 44               1610.775418               1326.057821  ...
# 45               1793.413331               1596.439230  ...
# 46               1941.070038               1851.935340  ...
# 47               2099.520945               2137.404771  ...
# 48               2273.605717               2460.757802  ...
# 49               2447.380591               2808.597761  ...
# 50               2592.064814               3136.143747  ...
# 51               2755.577491               3525.085448  ...
# 52               2928.600933               3965.783478  ...
# 53               3132.830890               4505.394612  ...
# 54               3378.520362               5167.046901  ...
# 55               3665.151149               5956.477432  ...
#
#     VirginStock_aluminium_frames_Irena_RL_high  \
# 36                                3.869332e+06
# 37                                4.189718e+06
# 38                                4.478818e+06
# 39                                4.766268e+06
# 40                                5.086162e+06
# 41                                5.404385e+06
# 42                                5.775671e+06
# 43                                6.145172e+06
# 44                                6.554751e+06
# 45                                6.962478e+06
# 46                                7.082136e+06
# 47                                7.200925e+06
# 48                                7.306443e+06
# 49                                7.411083e+06
# 50                                7.542652e+06
# 51                                7.673261e+06
# 52                                7.828643e+06
# 53                                7.983086e+06
# 54                                8.209092e+06
# 55                                8.434165e+06
#
#     VirginStock_Module_Irena_RL_high  Capacity_PV_ICE_base  \
# 36                      3.434049e+07          3.227709e+11
# 37                      3.759246e+07          3.320527e+11
# 38                      4.052893e+07          3.398931e+11
# 39                      4.345044e+07          3.468668e+11
# 40                      4.670271e+07          3.589963e+11
# 41                      4.994035e+07          3.714276e+11
# 42                      5.371821e+07          3.819063e+11
# 43                      5.748084e+07          3.936963e+11
# 44                      6.165271e+07          4.127856e+11
# 45                      6.580933e+07          4.302317e+11
# 46                      6.705096e+07          4.501559e+11
# 47                      6.828805e+07          4.696195e+11
# 48                      6.939532e+07          4.953493e+11
# 49                      7.049868e+07          5.210453e+11
# 50                      7.188011e+07          5.446454e+11
# 51                      7.325709e+07          5.677409e+11
# 52                      7.489019e+07          6.027703e+11
# 53                      7.651853e+07          6.369382e+11
# 54                      7.887612e+07          6.679522e+11
# 55                      8.122764e+07          6.977659e+11
#
#     Capacity_PV_ICE_high  Capacity_bifacialTrend_base  \
# 36          6.712000e+11                 3.227709e+11
# 37          7.328470e+11                 3.320527e+11
# 38          7.880465e+11                 3.398931e+11
# 39          8.421337e+11                 3.468668e+11
# 40          9.024567e+11                 3.589963e+11
# 41          9.628245e+11                 3.714276e+11
# 42          1.031894e+12                 3.819063e+11
# 43          1.101942e+12                 3.936963e+11
# 44          1.179625e+12                 4.127856e+11
# 45          1.255249e+12                 4.302317e+11
# 46          1.269438e+12                 4.501559e+11
# 47          1.282856e+12                 4.696195e+11
# 48          1.292662e+12                 4.953493e+11
# 49          1.301936e+12                 5.210453e+11
# 50          1.317884e+12                 5.446454e+11
# 51          1.332355e+12                 5.677409e+11
# 52          1.351188e+12                 6.027703e+11
# 53          1.367667e+12                 6.369382e+11
# 54          1.397213e+12                 6.679522e+11
# 55          1.423687e+12                 6.977659e+11
#
#     Capacity_bifacialTrend_high  Capacity_Irena_EL_base  \
# 36                 6.712000e+11            2.807495e+11
# 37                 7.328470e+11            2.821617e+11
# 38                 7.880465e+11            2.809766e+11
# 39                 8.421337e+11            2.785073e+11
# 40                 9.024567e+11            2.805313e+11
# 41                 9.628245e+11            2.812133e+11
# 42                 1.031894e+12            2.812187e+11
# 43                 1.101942e+12            2.799823e+11
# 44                 1.179625e+12            2.858318e+11
# 45                 1.255249e+12            2.907070e+11
# 46                 1.269438e+12            2.968358e+11
# 47                 1.282856e+12            3.024464e+11
# 48                 1.292662e+12            3.146302e+11
# 49                 1.301936e+12            3.267669e+11
# 50                 1.317884e+12            3.356216e+11
# 51                 1.332355e+12            3.447412e+11
# 52                 1.351188e+12            3.660828e+11
# 53                 1.367667e+12            3.875914e+11
# 54                 1.397213e+12            4.070563e+11
# 55                 1.423687e+12            4.262724e+11
#
#     Capacity_Irena_EL_high  Capacity_Irena_RL_base  Capacity_Irena_RL_high
# 36            6.162617e+11            3.205766e+11            6.687672e+11
# 37            6.639634e+11            3.289740e+11            7.293156e+11
# 38            7.021727e+11            3.353047e+11            7.826409e+11
# 39            7.366791e+11            3.408271e+11            8.346829e+11
# 40            7.743341e+11            3.512506e+11            8.923669e+11
# 41            8.077646e+11            3.606579e+11            9.482935e+11
# 42            8.484137e+11            3.696190e+11            1.013759e+12
# 43            8.846701e+11            3.774541e+11            1.076870e+12
# 44            9.255477e+11            3.923495e+11            1.146218e+12
# 45            9.623231e+11            4.060679e+11            1.212523e+12
# 46            9.338844e+11            4.206215e+11            1.214003e+12
# 47            9.022948e+11            4.339838e+11            1.211966e+12
# 48            8.654071e+11            4.529638e+11            1.203445e+12
# 49            8.264328e+11            4.706555e+11            1.190816e+12
# 50            7.919812e+11            4.835784e+11            1.179905e+12
# 51            7.565658e+11            4.951253e+11            1.164558e+12
# 52            7.263677e+11            5.172414e+11            1.150456e+12
# 53            6.963117e+11            5.380459e+11            1.132225e+12
# 54            6.828229e+11            5.557097e+11            1.126193e+12
# 55            6.704545e+11            5.725999e+11            1.117002e+12
#
# [20 rows x 200 columns]

# %% [markdown]
# ## Mining Capacity

# %%
USyearly.index = r1.scenario['base'].data['year']
UScum.index = r1.scenario['base'].data['year']

# %%
mining2020_aluminum = 65267000
mining2020_silver = 22260
mining2020_copper = 20000000
mining2020_silicon = 8000000

# %% [markdown]
# # PLOTTING GALORE

# %%
USyearly.keys()
# Out:
# Index(['Waste_glass_PV_ICE_base', 'Waste_silicon_PV_ICE_base',
#        'Waste_silver_PV_ICE_base', 'Waste_copper_PV_ICE_base',
#        'Waste_aluminium_frames_PV_ICE_base', 'Waste_Module_PV_ICE_base',
#        'Waste_glass_PV_ICE_high', 'Waste_silicon_PV_ICE_high',
#        'Waste_silver_PV_ICE_high', 'Waste_copper_PV_ICE_high',
#        ...
#        'VirginStock_silver_Irena_RL_base', 'VirginStock_copper_Irena_RL_base',
#        'VirginStock_aluminium_frames_Irena_RL_base',
#        'VirginStock_Module_Irena_RL_base', 'VirginStock_glass_Irena_RL_high',
#        'VirginStock_silicon_Irena_RL_high', 'VirginStock_silver_Irena_RL_high',
#        'VirginStock_copper_Irena_RL_high',
#        'VirginStock_aluminium_frames_Irena_RL_high',
#        'VirginStock_Module_Irena_RL_high'],
#       dtype='object', length=192)

# %%
plt.rcParams.update({'font.size': 10})
plt.rcParams['figure.figsize'] = (12, 8)
    
keyw='VirginStock_'
materials = ['glass', 'silicon', 'silver', 'copper', 'aluminium_frames']

fig, axs = plt.subplots(1,1, figsize=(4, 6), facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = .3, wspace=.2)


# Loop over CASES
name2 = 'PV_ICE_high'
name0 = 'PV_ICE_base'
# ROW 2, Aluminum and Silicon:        g-  4 aluminum k - 1 silicon   orange - 3 copper  gray - 2 silver
axs.plot(USyearly[keyw+materials[2]+'_'+name2]*100/mining2020_silver, 
         color = 'gray', linewidth=2.0, label='Silver')

axs.fill_between(USyearly.index, USyearly[keyw+materials[2]+'_'+name0]*100/mining2020_silver, USyearly[keyw+materials[2]+'_'+name2]*100/mining2020_silver,
                   color='gray', lw=3, alpha=.3)
    

axs.plot(USyearly[keyw+materials[1]+'_'+name2]*100/mining2020_silicon, 
         color = 'k', linewidth=2.0, label='Silicon')
axs.fill_between(USyearly.index, USyearly[keyw+materials[1]+'_'+name0]*100/mining2020_silicon, 
                                USyearly[keyw+materials[1]+'_'+name2]*100/mining2020_silicon,
                   color='k', lw=3, alpha=.5)



axs.plot(USyearly[keyw+materials[4]+'_'+name2]*100/mining2020_aluminum, 
         color = 'g', linewidth=2.0, label='Aluminum')

axs.fill_between(USyearly.index, USyearly[keyw+materials[4]+'_'+name0]*100/mining2020_aluminum, 
                                USyearly[keyw+materials[4]+'_'+name2]*100/mining2020_aluminum,
                   color='g', lw=3, alpha=.3)



axs.plot(USyearly[keyw+materials[3]+'_'+name2]*100/mining2020_copper, 
         color = 'orange', linewidth=2.0, label='Copper')

axs.fill_between(USyearly.index, USyearly[keyw+materials[3]+'_'+name0]*100/mining2020_copper, 
                                USyearly[keyw+materials[3]+'_'+name2]*100/mining2020_copper,
                   color='orange', lw=3, alpha=.3)



axs.set_xlim([2020,2050])
axs.legend()
#axs.set_yscale('log')

axs.set_ylabel('Virgin material needs as a percentage of \n 2020 global mining production capacity [%]')

fig.savefig(os.path.join(testfolder,'Fig_1x1_MaterialNeeds Ratio to Production_NREL2018.png'), dpi=600)

# %%
plt.rcParams.update({'font.size': 15})
plt.rcParams['figure.figsize'] = (15, 8)
keyw='VirginStock_'
materials = ['glass', 'silicon', 'silver', 'copper', 'aluminium_frames']


f, (a0, a1) = plt.subplots(1, 2, gridspec_kw={'width_ratios': [3, 1]})

########################    
# SUBPLOT 1
########################
#######################
   
# Loop over CASES
name2 = 'PV_ICE_high'
name0 = 'PV_ICE_base'


# SCENARIO 1 ***************
modulemat = (USyearly[keyw+materials[0]+'_'+name0]+USyearly[keyw+materials[1]+'_'+name0]+
            USyearly[keyw+materials[2]+'_'+name0]+USyearly[keyw+materials[3]+'_'+name0]+
            USyearly[keyw+materials[4]+'_'+name0])
glassmat = (USyearly[keyw+materials[0]+'_'+name0])
modulemat = modulemat/1000000
glassmat = glassmat/1000000 
a0.plot(USyearly.index, modulemat, 'k.', linewidth=5, label='S1: '+name0+' module mass')
a0.plot(USyearly.index, glassmat, 'k', linewidth=5, label='S1: '+name0+' glass mass only')
a0.fill_between(USyearly.index, glassmat, modulemat, color='k', alpha=0.3,
                 interpolate=True)

# SCENARIO 2 ***************
modulemat = (USyearly[keyw+materials[0]+'_'+name2]+USyearly[keyw+materials[1]+'_'+name2]+
            USyearly[keyw+materials[2]+'_'+name2]+USyearly[keyw+materials[3]+'_'+name2]+
            USyearly[keyw+materials[4]+'_'+name2])
glassmat = (USyearly[keyw+materials[0]+'_'+name2])
modulemat = modulemat/1000000
glassmat = glassmat/1000000 
a0.plot(USyearly.index, modulemat, 'c.', linewidth=5, label='S2: '+name2+' module mass')
a0.plot(USyearly.index, glassmat, 'c', linewidth=5, label='S2: '+name2+' glass mass only')
a0.fill_between(USyearly.index, glassmat, modulemat, color='c', alpha=0.3,
                 interpolate=True)

a0.legend()
a0.set_title('Yearly Virgin Material Needs by Scenario')
a0.set_ylabel('Mass [Million Tonnes]')
a0.set_xlim([2020, 2050])
a0.set_xlabel('Years')
    
    
########################    
# SUBPLOT 2
########################
#######################
# Calculate    

cumulations2050 = {}
for ii in range(0, len(materials)):
    matcum = []
    matcum.append(UScum[keyw+materials[ii]+'_'+name0].loc[2050])
    matcum.append(UScum[keyw+materials[ii]+'_'+name2].loc[2050])
    cumulations2050[materials[ii]] = matcum

dfcumulations2050 = pd.DataFrame.from_dict(cumulations2050) 
dfcumulations2050 = dfcumulations2050/1000000   # in Million Tonnes

dfcumulations2050['bottom1'] = dfcumulations2050['glass']
dfcumulations2050['bottom2'] = dfcumulations2050['bottom1']+dfcumulations2050['aluminium_frames']
dfcumulations2050['bottom3'] = dfcumulations2050['bottom2']+dfcumulations2050['silicon']
dfcumulations2050['bottom4'] = dfcumulations2050['bottom3']+dfcumulations2050['copper']


## Plot BARS Stuff
ind=np.arange(2)
width=0.35 # width of the bars.
p0 = a1.bar(ind, dfcumulations2050['glass'], width, color='c')
p1 = a1.bar(ind, dfcumulations2050['aluminium_frames'], width,
             bottom=dfcumulations2050['bottom1'])
p2 = a1.bar(ind, dfcumulations2050['silicon'], width,
             bottom=dfcumulations2050['bottom2'])
p3 = a1.bar(ind, dfcumulations2050['copper'], width,
             bottom=dfcumulations2050['bottom3'])
p4 = a1.bar(ind, dfcumulations2050['silver'], width,
             bottom=dfcumulations2050['bottom4'])

a1.yaxis.set_label_position("right")
a1.yaxis.tick_right()
a1.set_ylabel('Virgin Material Cumulative Needs 2020-2050 [Million Tonnes]')
a1.set_xlabel('Scenario')
a1.set_xticks(ind, ('S1', 'S2'))
#plt.yticks(np.arange(0, 81, 10))
a1.legend((p0[0], p1[0], p2[0], p3[0], p4[0] ), ('Glass', 'aluminium_frames', 'Silicon','Copper','Silver'))

f.tight_layout()

fig.savefig(os.path.join(testfolder,'Fig_2x1_Yearly Virgin Material Needs by Scenario and Cumulatives_NREL2018.png'), dpi=600)


print("Cumulative Virgin Needs by 2050 Million Tones by Scenario")
dfcumulations2050[['glass','silicon','silver','copper','aluminium_frames']].sum(axis=1)
# Out:
# Cumulative Virgin Needs by 2050 Million Tones by Scenario
# 0    42.726421
# 1    84.963062
# dtype: float64

# %%
plt.rcParams.update({'font.size': 15})
plt.rcParams['figure.figsize'] = (15, 8)
keyw='Waste_EOL_'
materials = ['glass', 'silicon', 'silver', 'copper', 'aluminium_frames']


f, (a0, a1) = plt.subplots(1, 2, gridspec_kw={'width_ratios': [3, 1]})

########################    
# SUBPLOT 1
########################
#######################
   
# Loop over CASES
name2 = 'PV_ICE_high'
name0 = 'PV_ICE_base'


# SCENARIO 1 ***************
modulemat = (USyearly[keyw+materials[0]+'_'+name0]+USyearly[keyw+materials[1]+'_'+name0]+
            USyearly[keyw+materials[2]+'_'+name0]+USyearly[keyw+materials[3]+'_'+name0]+
            USyearly[keyw+materials[4]+'_'+name0])
glassmat = (USyearly[keyw+materials[0]+'_'+name0])
modulemat = modulemat/1000000
glassmat = glassmat/1000000 
a0.plot(USyearly.index, modulemat, 'k.', linewidth=5, label='S1: '+name0+' module mass')
a0.plot(USyearly.index, glassmat, 'k', linewidth=5, label='S1: '+name0+' glass mass only')
a0.fill_between(USyearly.index, glassmat, modulemat, color='k', alpha=0.3,
                 interpolate=True)

# SCENARIO 2 ***************
modulemat = (USyearly[keyw+materials[0]+'_'+name2]+USyearly[keyw+materials[1]+'_'+name2]+
            USyearly[keyw+materials[2]+'_'+name2]+USyearly[keyw+materials[3]+'_'+name2]+
            USyearly[keyw+materials[4]+'_'+name2])
glassmat = (USyearly[keyw+materials[0]+'_'+name2])
modulemat = modulemat/1000000
glassmat = glassmat/1000000 
a0.plot(USyearly.index, modulemat, 'c.', linewidth=5, label='S2: '+name2+' module mass')
a0.plot(USyearly.index, glassmat, 'c', linewidth=5, label='S2: '+name2+' glass mass only')
a0.fill_between(USyearly.index, glassmat, modulemat, color='c', alpha=0.3,
                 interpolate=True)

a0.legend()
a0.set_title('Yearly End of Life Material by Scenario')
a0.set_ylabel('Mass [Million Tonnes]')
a0.set_xlim([2020, 2050])
a0.set_xlabel('Years')
    
    
########################    
# SUBPLOT 2
########################
#######################
# Calculate    

cumulations2050 = {}
for ii in range(0, len(materials)):
    matcum = []
    matcum.append(UScum[keyw+materials[ii]+'_'+name0].loc[2050])
    matcum.append(UScum[keyw+materials[ii]+'_'+name2].loc[2050])
    cumulations2050[materials[ii]] = matcum

dfcumulations2050 = pd.DataFrame.from_dict(cumulations2050) 
dfcumulations2050 = dfcumulations2050/1000000   # in Million Tonnes

dfcumulations2050['bottom1'] = dfcumulations2050['glass']
dfcumulations2050['bottom2'] = dfcumulations2050['bottom1']+dfcumulations2050['aluminium_frames']
dfcumulations2050['bottom3'] = dfcumulations2050['bottom2']+dfcumulations2050['silicon']
dfcumulations2050['bottom4'] = dfcumulations2050['bottom3']+dfcumulations2050['copper']


## Plot BARS Stuff
ind=np.arange(2)
width=0.35 # width of the bars.
p0 = a1.bar(ind, dfcumulations2050['glass'], width, color='c')
p1 = a1.bar(ind, dfcumulations2050['aluminium_frames'], width,
             bottom=dfcumulations2050['bottom1'])
p2 = a1.bar(ind, dfcumulations2050['silicon'], width,
             bottom=dfcumulations2050['bottom2'])
p3 = a1.bar(ind, dfcumulations2050['copper'], width,
             bottom=dfcumulations2050['bottom3'])
p4 = a1.bar(ind, dfcumulations2050['silver'], width,
             bottom=dfcumulations2050['bottom4'])

a1.yaxis.set_label_position("right")
a1.yaxis.tick_right()
a1.set_ylabel('Cumulative End of Life Material by 2050 [Million Tonnes]')
a1.set_xlabel('Scenario')
a1.set_xticks(ind, ('S1', 'S2'))
#plt.yticks(np.arange(0, 81, 10))
a1.legend((p0[0], p1[0], p2[0], p3[0], p4[0] ), ('Glass', 'aluminium_frames', 'Silicon','Copper','Silver'))

f.tight_layout()

fig.savefig(os.path.join(testfolder,'Fig_2x1_Yearly EoL Waste by SCenario and Cumulatives_NREL2018.png'), dpi=600)


print("Cumulative Waste by EoL 2050 Million Tones by Scenario")
dfcumulations2050[['glass','silicon','silver','copper','aluminium_frames']].sum(axis=1)
# Out:
# Cumulative Waste by EoL 2050 Million Tones by Scenario
# 0    5.584698
# 1    7.820177
# dtype: float64

# %%
# Loop over CASES
name0 = 'PV_ICE_base'
name2 = 'PV_ICE_high'
name3 = 'Irena_EL_high'
name4 = 'Irena_RL_high'

cumulations2050 = {}
for ii in range(0, len(materials)):
    matcum = []
    matcum.append(UScum[keyw+materials[ii]+'_'+name0].loc[2016])
    matcum.append(UScum[keyw+materials[ii]+'_'+name2].loc[2016])
    matcum.append(UScum[keyw+materials[ii]+'_'+name3].loc[2016])
    matcum.append(UScum[keyw+materials[ii]+'_'+name4].loc[2016])
    
    cumulations2050[materials[ii]] = matcum

dfcumulations2050 = pd.DataFrame.from_dict(cumulations2050) 
dfcumulations2050 = dfcumulations2050/1000000   # in Million Tonnes
dfcumulations2050['Module'] = dfcumulations2050.sum(axis=1)
dfcumulations2050['Module']
# Out:
# 0    0.010549
# 1    0.010549
# 2    0.032417
# 3    0.002463
# Name: Module, dtype: float64

# %%
# Loop over CASES
name0 = 'PV_ICE_base'
name2 = 'PV_ICE_high'
name3 = 'Irena_EL_high'
name4 = 'Irena_RL_high'

cumulations2050 = {}
for ii in range(0, len(materials)):
    matcum = []
    matcum.append(UScum[keyw+materials[ii]+'_'+name0].loc[2020])
    matcum.append(UScum[keyw+materials[ii]+'_'+name2].loc[2020])
    matcum.append(UScum[keyw+materials[ii]+'_'+name3].loc[2020])
    matcum.append(UScum[keyw+materials[ii]+'_'+name4].loc[2020])
    
    cumulations2050[materials[ii]] = matcum

dfcumulations2050 = pd.DataFrame.from_dict(cumulations2050) 
dfcumulations2050 = dfcumulations2050/1000000   # in Million Tonnes
dfcumulations2050['Module'] = dfcumulations2050.sum(axis=1)
dfcumulations2050['Module']
# Out:
# 0    0.029290
# 1    0.029290
# 2    0.145703
# 3    0.009968
# Name: Module, dtype: float64

# %%
# Loop over CASES
name0 = 'PV_ICE_base'
name2 = 'PV_ICE_high'
name3 = 'Irena_EL_high'
name4 = 'Irena_RL_high'

cumulations2050 = {}
for ii in range(0, len(materials)):
    matcum = []
    matcum.append(UScum[keyw+materials[ii]+'_'+name0].loc[2030])
    matcum.append(UScum[keyw+materials[ii]+'_'+name2].loc[2030])
    matcum.append(UScum[keyw+materials[ii]+'_'+name3].loc[2030])
    matcum.append(UScum[keyw+materials[ii]+'_'+name4].loc[2030])
    
    cumulations2050[materials[ii]] = matcum

dfcumulations2050 = pd.DataFrame.from_dict(cumulations2050) 
dfcumulations2050 = dfcumulations2050/1000000   # in Million Tonnes
dfcumulations2050['Module'] = dfcumulations2050.sum(axis=1)
dfcumulations2050['Module']
# Out:
# 0    0.248953
# 1    0.248981
# 2    2.718572
# 3    0.322144
# Name: Module, dtype: float64

# %%
# Loop over CASES
name0 = 'PV_ICE_base'
name2 = 'PV_ICE_high'
name3 = 'Irena_EL_high'
name4 = 'Irena_RL_high'

cumulations2050 = {}
for ii in range(0, len(materials)):
    matcum = []
    matcum.append(UScum[keyw+materials[ii]+'_'+name0].loc[2040])
    matcum.append(UScum[keyw+materials[ii]+'_'+name2].loc[2040])
    matcum.append(UScum[keyw+materials[ii]+'_'+name3].loc[2040])
    matcum.append(UScum[keyw+materials[ii]+'_'+name4].loc[2040])
    
    cumulations2050[materials[ii]] = matcum

dfcumulations2050 = pd.DataFrame.from_dict(cumulations2050) 
dfcumulations2050 = dfcumulations2050/1000000   # in Million Tonnes
dfcumulations2050['Module'] = dfcumulations2050.sum(axis=1)
dfcumulations2050['Module']
# Out:
# 0     2.182571
# 1     2.224061
# 2    17.500240
# 3     4.543507
# Name: Module, dtype: float64

# %%
# Loop over CASES
name0 = 'PV_ICE_base'
name2 = 'PV_ICE_high'
name3 = 'Irena_EL_high'
name4 = 'Irena_RL_high'

cumulations2050 = {}
for ii in range(0, len(materials)):
    matcum = []
    matcum.append(UScum[keyw+materials[ii]+'_'+name0].loc[2050])
    matcum.append(UScum[keyw+materials[ii]+'_'+name2].loc[2050])
    matcum.append(UScum[keyw+materials[ii]+'_'+name3].loc[2050])
    matcum.append(UScum[keyw+materials[ii]+'_'+name4].loc[2050])
    
    cumulations2050[materials[ii]] = matcum

dfcumulations2050 = pd.DataFrame.from_dict(cumulations2050) 
dfcumulations2050 = dfcumulations2050/1000000   # in Million Tonnes
dfcumulations2050['Module'] = dfcumulations2050.sum(axis=1)
dfcumulations2050['Module']
# Out:
# 0     5.584698
# 1     7.820177
# 2    47.163072
# 3    24.143763
# Name: Module, dtype: float64

# %%
plt.rcParams.update({'font.size': 15})
plt.rcParams['figure.figsize'] = (15, 8)
keyw='Waste_'
materials = ['glass', 'silicon', 'silver', 'copper', 'aluminium_frames']


f, (a0, a1) = plt.subplots(1, 2, gridspec_kw={'width_ratios': [3, 1]})

########################    
# SUBPLOT 1
########################
#######################
   
# Loop over CASES
name2 = 'PV_ICE_high'
name0 = 'PV_ICE_base'


# SCENARIO 1 ***************
modulemat = (USyearly[keyw+materials[0]+'_'+name0]+USyearly[keyw+materials[1]+'_'+name0]+
            USyearly[keyw+materials[2]+'_'+name0]+USyearly[keyw+materials[3]+'_'+name0]+
            USyearly[keyw+materials[4]+'_'+name0])
glassmat = (USyearly[keyw+materials[0]+'_'+name0])
modulemat = modulemat/1000000
glassmat = glassmat/1000000 
a0.plot(USyearly.index, modulemat, 'k.', linewidth=5, label='S1: '+name0+' module mass')
a0.plot(USyearly.index, glassmat, 'k', linewidth=5, label='S1: '+name0+' glass mass only')
a0.fill_between(USyearly.index, glassmat, modulemat, color='k', alpha=0.3,
                 interpolate=True)

# SCENARIO 2 ***************
modulemat = (USyearly[keyw+materials[0]+'_'+name2]+USyearly[keyw+materials[1]+'_'+name2]+
            USyearly[keyw+materials[2]+'_'+name2]+USyearly[keyw+materials[3]+'_'+name2]+
            USyearly[keyw+materials[4]+'_'+name2])
glassmat = (USyearly[keyw+materials[0]+'_'+name2])
modulemat = modulemat/1000000
glassmat = glassmat/1000000 
a0.plot(USyearly.index, modulemat, 'c.', linewidth=5, label='S2: '+name2+' module mass')
a0.plot(USyearly.index, glassmat, 'c', linewidth=5, label='S2: '+name2+' glass mass only')
a0.fill_between(USyearly.index, glassmat, modulemat, color='c', alpha=0.3,
                 interpolate=True)

a0.legend()
a0.set_title('Yearly Manufacturing Scrap and EoL Material by Scenario')
a0.set_ylabel('Mass [Million Tonnes]')
a0.set_xlim([2020, 2050])
a0.set_xlabel('Years')
    
    
########################    
# SUBPLOT 2
########################
#######################
# Calculate    

cumulations2050 = {}
for ii in range(0, len(materials)):
    matcum = []
    matcum.append(UScum[keyw+materials[ii]+'_'+name0].loc[2050])
    matcum.append(UScum[keyw+materials[ii]+'_'+name2].loc[2050])
    cumulations2050[materials[ii]] = matcum

dfcumulations2050 = pd.DataFrame.from_dict(cumulations2050) 
dfcumulations2050 = dfcumulations2050/1000000   # in Million Tonnes

dfcumulations2050['bottom1'] = dfcumulations2050['glass']
dfcumulations2050['bottom2'] = dfcumulations2050['bottom1']+dfcumulations2050['aluminium_frames']
dfcumulations2050['bottom3'] = dfcumulations2050['bottom2']+dfcumulations2050['silicon']
dfcumulations2050['bottom4'] = dfcumulations2050['bottom3']+dfcumulations2050['copper']


## Plot BARS Stuff
ind=np.arange(2)
width=0.35 # width of the bars.
p0 = a1.bar(ind, dfcumulations2050['glass'], width, color='c')
p1 = a1.bar(ind, dfcumulations2050['aluminium_frames'], width,
             bottom=dfcumulations2050['bottom1'])
p2 = a1.bar(ind, dfcumulations2050['silicon'], width,
             bottom=dfcumulations2050['bottom2'])
p3 = a1.bar(ind, dfcumulations2050['copper'], width,
             bottom=dfcumulations2050['bottom3'])
p4 = a1.bar(ind, dfcumulations2050['silver'], width,
             bottom=dfcumulations2050['bottom4'])

a1.yaxis.set_label_position("right")
a1.yaxis.tick_right()
a1.set_ylabel('Cumulative Manufacturing Scrap and EoL Material \n by 2050 [Million Tonnes]')
a1.set_xlabel('Scenario')
a1.set_xticks(ind, ('S1', 'S2'))
#plt.yticks(np.arange(0, 81, 10))
a1.legend((p0[0], p1[0], p2[0], p3[0], p4[0] ), ('Glass', 'aluminium_frames', 'Silicon','Copper','Silver'))

f.tight_layout()

fig.savefig(os.path.join(testfolder,'Fig_2x1_Yearly MFG and EOL Material by Scenario and Cumulatives_NREL2018.png'), dpi=600)


print("Cumulative Waste Scrap and EoL 2050 Million Tones by Scenario")
dfcumulations2050[['glass','silicon','silver','copper','aluminium_frames']].sum(axis=1)
# Out:
# Cumulative Waste Scrap and EoL 2050 Million Tones by Scenario
# 0     6.888243
# 1    10.302106
# dtype: float64

# %%
plt.rcParams.update({'font.size': 15})
plt.rcParams['figure.figsize'] = (15, 8)
keyw='Waste_MFG_'
materials = ['glass', 'silicon', 'silver', 'copper', 'aluminium_frames']


f, (a0, a1) = plt.subplots(1, 2, gridspec_kw={'width_ratios': [3, 1]})

########################    
# SUBPLOT 1
########################
#######################
   
# Loop over CASES
name2 = 'PV_ICE_high'
name0 = 'PV_ICE_base'


# SCENARIO 1 ***************
modulemat = (USyearly[keyw+materials[0]+'_'+name0]+USyearly[keyw+materials[1]+'_'+name0]+
            USyearly[keyw+materials[2]+'_'+name0]+USyearly[keyw+materials[3]+'_'+name0]+
            USyearly[keyw+materials[4]+'_'+name0])
glassmat = (USyearly[keyw+materials[0]+'_'+name0])
modulemat = modulemat/1000000
glassmat = glassmat/1000000 
a0.plot(USyearly.index, modulemat, 'k.', linewidth=5, label='S1: '+name0+' module mass')
a0.plot(USyearly.index, glassmat, 'k', linewidth=5, label='S1: '+name0+' glass mass only')
a0.fill_between(USyearly.index, glassmat, modulemat, color='k', alpha=0.3,
                 interpolate=True)

# SCENARIO 2 ***************
modulemat = (USyearly[keyw+materials[0]+'_'+name2]+USyearly[keyw+materials[1]+'_'+name2]+
            USyearly[keyw+materials[2]+'_'+name2]+USyearly[keyw+materials[3]+'_'+name2]+
            USyearly[keyw+materials[4]+'_'+name2])
glassmat = (USyearly[keyw+materials[0]+'_'+name2])
modulemat = modulemat/1000000
glassmat = glassmat/1000000 
a0.plot(USyearly.index, modulemat, 'c.', linewidth=5, label='S2: '+name2+' module mass')
a0.plot(USyearly.index, glassmat, 'c', linewidth=5, label='S2: '+name2+' glass mass only')
a0.fill_between(USyearly.index, glassmat, modulemat, color='c', alpha=0.3,
                 interpolate=True)

a0.legend()
a0.set_title('Yearly Manufacturing Scrap by Scenario')
a0.set_ylabel('Mass [Million Tonnes]')
a0.set_xlim([2020, 2050])
a0.set_xlabel('Years')
    
    
########################    
# SUBPLOT 2
########################
#######################
# Calculate    

cumulations2050 = {}
for ii in range(0, len(materials)):
    matcum = []
    matcum.append(UScum[keyw+materials[ii]+'_'+name0].loc[2050])
    matcum.append(UScum[keyw+materials[ii]+'_'+name2].loc[2050])
    cumulations2050[materials[ii]] = matcum

dfcumulations2050 = pd.DataFrame.from_dict(cumulations2050) 
dfcumulations2050 = dfcumulations2050/1000000   # in Million Tonnes

dfcumulations2050['bottom1'] = dfcumulations2050['glass']
dfcumulations2050['bottom2'] = dfcumulations2050['bottom1']+dfcumulations2050['aluminium_frames']
dfcumulations2050['bottom3'] = dfcumulations2050['bottom2']+dfcumulations2050['silicon']
dfcumulations2050['bottom4'] = dfcumulations2050['bottom3']+dfcumulations2050['copper']


## Plot BARS Stuff
ind=np.arange(2)
width=0.35 # width of the bars.
p0 = a1.bar(ind, dfcumulations2050['glass'], width, color='c')
p1 = a1.bar(ind, dfcumulations2050['aluminium_frames'], width,
             bottom=dfcumulations2050['bottom1'])
p2 = a1.bar(ind, dfcumulations2050['silicon'], width,
             bottom=dfcumulations2050['bottom2'])
p3 = a1.bar(ind, dfcumulations2050['copper'], width,
             bottom=dfcumulations2050['bottom3'])
p4 = a1.bar(ind, dfcumulations2050['silver'], width,
             bottom=dfcumulations2050['bottom4'])

a1.yaxis.set_label_position("right")
a1.yaxis.tick_right()
a1.set_ylabel('Cumulative Manufacturing Scrap by 2050 [Million Tonnes]')
a1.set_xlabel('Scenario')
a1.set_xticks(ind, ('S1', 'S2'))
#plt.yticks(np.arange(0, 81, 10))
a1.legend((p0[0], p1[0], p2[0], p3[0], p4[0] ), ('Glass', 'aluminium_frames', 'Silicon','Copper','Silver'))

f.tight_layout()

fig.savefig(os.path.join(testfolder,'Fig_2x1_YYearly MFG Waste by Scenario and Cumulatives_NREL2018.png'), dpi=600)


print("Cumulative MFG Scrap 2050 Million Tones by Scenario")
dfcumulations2050[['glass','silicon','silver','copper','aluminium_frames']].sum(axis=1)
# Out:
# Cumulative MFG Scrap 2050 Million Tones by Scenario
# 0    1.303545
# 1    2.481929
# dtype: float64

# %%
plt.rcParams.update({'font.size': 15})
plt.rcParams['figure.figsize'] = (15, 8)
keyw='VirginStock_'
materials = ['glass', 'silicon', 'silver', 'copper', 'aluminium_frames']

fig, axs = plt.subplots(3,2, figsize=(18, 10), facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = .5, wspace=.2)
axs = axs.ravel()

########################    
# SUBPLOT 1
########################
#######################
   
# Loop over CASES
name2 = 'PV_ICE_high'
name0 = 'PV_ICE_base'
name3 = 'Irena_EL_high'
name4 = 'Irena_RL_high'


# SCENARIO 1 ***************

modulemat = (USyearly[keyw+materials[0]+'_'+name0]+USyearly[keyw+materials[1]+'_'+name0]+
            USyearly[keyw+materials[2]+'_'+name0]+USyearly[keyw+materials[3]+'_'+name0]+
            USyearly[keyw+materials[4]+'_'+name0])
glassmat = (USyearly[keyw+materials[0]+'_'+name0])
modulemat = modulemat/1000000
glassmat = glassmat/1000000 
axs[0].plot(USyearly.index, modulemat, 'k.', linewidth=5, label='S1: '+name0+' module mass')
axs[0].plot(USyearly.index, glassmat, 'k', linewidth=5, label='S1: '+name0+' glass mass only')
axs[0].fill_between(USyearly.index, glassmat, modulemat, color='k', alpha=0.3,
                 interpolate=True)

# SCENARIO 2 ***************
modulemat = (USyearly[keyw+materials[0]+'_'+name2]+USyearly[keyw+materials[1]+'_'+name2]+
            USyearly[keyw+materials[2]+'_'+name2]+USyearly[keyw+materials[3]+'_'+name2]+
            USyearly[keyw+materials[4]+'_'+name2])
glassmat = (USyearly[keyw+materials[0]+'_'+name2])
modulemat = modulemat/1000000
glassmat = glassmat/1000000 
axs[0].plot(USyearly.index, modulemat, 'c.', linewidth=5, label='S2: '+name2+' module mass')
axs[0].plot(USyearly.index, glassmat, 'c', linewidth=5, label='S2: '+name2+' glass mass only')
axs[0].fill_between(USyearly.index, glassmat, modulemat, color='c', alpha=0.3,
                 interpolate=True)

#axs[0].legend()
axs[0].set_title('Yearly Virgin Material Needs by Scenario')
axs[0].set_ylabel('Mass [Million Tonnes]')
axs[0].set_xlim([2020, 2050])
axs[0].set_xlabel('Years')
    
# SCENARIO 3 ***************
modulemat = (USyearly[keyw+materials[0]+'_'+name3]+USyearly[keyw+materials[1]+'_'+name3]+
            USyearly[keyw+materials[2]+'_'+name3]+USyearly[keyw+materials[3]+'_'+name3]+
            USyearly[keyw+materials[4]+'_'+name3])
glassmat = (USyearly[keyw+materials[0]+'_'+name3])
modulemat = modulemat/1000000
glassmat = glassmat/1000000 
axs[1].plot(USyearly.index, modulemat, 'g.', linewidth=5, label='S2: '+name3+' module mass')
axs[1].plot(USyearly.index, glassmat, 'g', linewidth=5, label='S2: '+name3+' glass mass only')
axs[1].fill_between(USyearly.index, glassmat, modulemat, color='g', alpha=0.3,
                 interpolate=True)

# SCENARIO 4 ***************
modulemat = (USyearly[keyw+materials[0]+'_'+name4]+USyearly[keyw+materials[1]+'_'+name4]+
            USyearly[keyw+materials[2]+'_'+name4]+USyearly[keyw+materials[3]+'_'+name4]+
            USyearly[keyw+materials[4]+'_'+name4])
glassmat = (USyearly[keyw+materials[0]+'_'+name4])
modulemat = modulemat/1000000
glassmat = glassmat/1000000 
axs[1].plot(USyearly.index, modulemat, 'b.', linewidth=5, label='S4: '+name4+' module mass')
axs[1].plot(USyearly.index, glassmat, 'b', linewidth=5, label='S4: '+name4+' glass mass only')
axs[1].fill_between(USyearly.index, glassmat, modulemat, color='b', alpha=0.3,
                 interpolate=True)

#axs[1].legend()
axs[1].set_title('Yearly Virgin Material Needs by Scenario')
axs[1].set_ylabel('Mass [Million Tonnes]')
axs[1].set_xlim([2020, 2050])
axs[1].set_xlabel('Years')

#### ROW 2
keyw='Waste_EOL_'


# SCENARIO 1 ***************

modulemat = (USyearly[keyw+materials[0]+'_'+name0]+USyearly[keyw+materials[1]+'_'+name0]+
            USyearly[keyw+materials[2]+'_'+name0]+USyearly[keyw+materials[3]+'_'+name0]+
            USyearly[keyw+materials[4]+'_'+name0])
glassmat = (USyearly[keyw+materials[0]+'_'+name0])
modulemat = modulemat/1000000
glassmat = glassmat/1000000 
axs[2].plot(USyearly.index, modulemat, 'k.', linewidth=5, label='S1: '+name0+' module mass')
axs[2].plot(USyearly.index, glassmat, 'k', linewidth=5, label='S1: '+name0+' glass mass only')
axs[2].fill_between(USyearly.index, glassmat, modulemat, color='k', alpha=0.3,
                 interpolate=True)

# SCENARIO 2 ***************
modulemat = (USyearly[keyw+materials[0]+'_'+name2]+USyearly[keyw+materials[1]+'_'+name2]+
            USyearly[keyw+materials[2]+'_'+name2]+USyearly[keyw+materials[3]+'_'+name2]+
            USyearly[keyw+materials[4]+'_'+name2])
glassmat = (USyearly[keyw+materials[0]+'_'+name2])
modulemat = modulemat/1000000
glassmat = glassmat/1000000 
axs[2].plot(USyearly.index, modulemat, 'c.', linewidth=5, label='S2: '+name2+' module mass')
axs[2].plot(USyearly.index, glassmat, 'c', linewidth=5, label='S2: '+name2+' glass mass only')
axs[2].fill_between(USyearly.index, glassmat, modulemat, color='c', alpha=0.3,
                 interpolate=True)

#axs[0].legend()
axs[2].set_title('Yearly EoL Material by Scenario')
axs[2].set_ylabel('Mass [Million Tonnes]')
axs[2].set_xlim([2020, 2050])
axs[2].set_xlabel('Years')
    
# SCENARIO 3 ***************
modulemat = (USyearly[keyw+materials[0]+'_'+name3]+USyearly[keyw+materials[1]+'_'+name3]+
            USyearly[keyw+materials[2]+'_'+name3]+USyearly[keyw+materials[3]+'_'+name3]+
            USyearly[keyw+materials[4]+'_'+name3])
glassmat = (USyearly[keyw+materials[0]+'_'+name3])
modulemat = modulemat/1000000
glassmat = glassmat/1000000 
axs[3].plot(USyearly.index, modulemat, 'g.', linewidth=5, label='S2: '+name3+' module mass')
axs[3].plot(USyearly.index, glassmat, 'g', linewidth=5, label='S2: '+name3+' glass mass only')
axs[3].fill_between(USyearly.index, glassmat, modulemat, color='g', alpha=0.3,
                 interpolate=True)



# SCENARIO 4 ***************
modulemat = (USyearly[keyw+materials[0]+'_'+name4]+USyearly[keyw+materials[1]+'_'+name4]+
            USyearly[keyw+materials[2]+'_'+name4]+USyearly[keyw+materials[3]+'_'+name4]+
            USyearly[keyw+materials[4]+'_'+name4])
glassmat = (USyearly[keyw+materials[0]+'_'+name4])
modulemat = modulemat/1000000
glassmat = glassmat/1000000 
axs[3].plot(USyearly.index, modulemat, 'b.', linewidth=5, label='S4: '+name4+' module mass')
axs[3].plot(USyearly.index, glassmat, 'b', linewidth=5, label='S4: '+name4+' glass mass only')
axs[3].fill_between(USyearly.index, glassmat, modulemat, color='b', alpha=0.3,
                 interpolate=True)

#axs[1].legend()
axs[3].set_title('Yearly EoL Material by Scenario')
axs[3].set_ylabel('Mass [Million Tonnes]')
axs[3].set_xlim([2020, 2050])
axs[3].set_xlabel('Years')



#### ROW 3
keyw='Waste_MFG_'


# SCENARIO 1 ***************

modulemat = (USyearly[keyw+materials[0]+'_'+name0]+USyearly[keyw+materials[1]+'_'+name0]+
            USyearly[keyw+materials[2]+'_'+name0]+USyearly[keyw+materials[3]+'_'+name0]+
            USyearly[keyw+materials[4]+'_'+name0])
glassmat = (USyearly[keyw+materials[0]+'_'+name0])
modulemat = modulemat/1000000
glassmat = glassmat/1000000 
axs[4].plot(USyearly.index, modulemat, 'k.', linewidth=5, label='S1: '+name0+' module mass')
axs[4].plot(USyearly.index, glassmat, 'k', linewidth=5, label='S1: '+name0+' glass mass only')
axs[4].fill_between(USyearly.index, glassmat, modulemat, color='k', alpha=0.3,
                 interpolate=True)

# SCENARIO 2 ***************
modulemat = (USyearly[keyw+materials[0]+'_'+name2]+USyearly[keyw+materials[1]+'_'+name2]+
            USyearly[keyw+materials[2]+'_'+name2]+USyearly[keyw+materials[3]+'_'+name2]+
            USyearly[keyw+materials[4]+'_'+name2])
glassmat = (USyearly[keyw+materials[0]+'_'+name2])
modulemat = modulemat/1000000
glassmat = glassmat/1000000 
axs[4].plot(USyearly.index, modulemat, 'c.', linewidth=5, label='S2: '+name2+' module mass')
axs[4].plot(USyearly.index, glassmat, 'c', linewidth=5, label='S2: '+name2+' glass mass only')
axs[4].fill_between(USyearly.index, glassmat, modulemat, color='c', alpha=0.3,
                 interpolate=True)

#axs[0].legend()
axs[4].set_title('Yearly Manufacturing Waste by Scenario')
axs[4].set_ylabel('Mass [Million Tonnes]')
axs[4].set_xlim([2020, 2050])
axs[4].set_xlabel('Years')
    


########################    
# SUBPLOT 2
########################
#######################
# Calculate    

fig.savefig(os.path.join(testfolder,'Fig_2x1_Yearly Virgin Material Needs by Scenario and Cumulatives_NREL2018.png'), dpi=600)


print("Cumulative Virgin Needs by 2050 Million Tones by Scenario")
# Out:
# Cumulative Virgin Needs by 2050 Million Tones by Scenario

# %% [markdown]
# ### TABLES

# %%
# 3 sig figs

USyearly3sig = USyearly.copy()
UScum3sig = UScum.copy()
N = 2

UScum3sig = UScum3sig.drop(UScum3sig.index[0])
USyearly3sig = USyearly3sig.drop(USyearly3sig.index[0])

UScum3sig = UScum3sig.loc[:, ~UScum3sig.columns.str.startswith('Waste_MFG_')]
USyearly3sig = USyearly3sig.loc[:, ~USyearly3sig.columns.str.startswith('Waste_MFG_')]

USyearly3sig = USyearly3sig.applymap(lambda x: round(x, N - int(np.floor(np.log10(abs(x))))))
USyearly3sig = USyearly3sig.applymap(lambda x: int(x))

UScum3sig = UScum3sig.applymap(lambda x: round(x, N - int(np.floor(np.log10(abs(x))))))
UScum3sig = UScum3sig.applymap(lambda x: int(x))

# %%
materials = ['Module','glass', 'aluminium_frames', 'copper', 'silicon', 'silver']
scencases = ['_base', '_high']

print(" Appendix Table I: Metric Tonnes Installed in field in 2030")
print(" ########################################################### \n")
#Loop over scenarios
for zz in range(0, len(scencases)):
    scencase = scencases[zz]
    for kk in range (0, len(objects)):
        obj = objects[kk].name
        print("SCENARIO :", obj),      print("~~~~>>>> Case ", scencase)


        print("********************************")
        print("********************************")

        modulemat = 0
        for ii in range(0, len(materials)):
            installedmat = (UScum3sig['VirginStock_'+materials[ii]+'_'+obj+scencase].loc[2030]-
                  UScum3sig['Waste_'+materials[ii]+'_'+obj+'_base'].loc[2030])
            print(materials[ii], ':', round(installedmat/1000)*1000, 'tons')

        print("Capacity in Year 2030 [GW]:", round(UScum3sig['Capacity_'+obj+scencase].loc[2030]/1e9))
        print("Capacity in Year 2050 [GW]:", round(UScum3sig['Capacity_'+obj+scencase].loc[2050]/1e9))
        print("****************************\n")
# Out:
#  Appendix Table I: Metric Tonnes Installed in field in 2030
#  ###########################################################
#
# SCENARIO : PV_ICE
# ~~~~>>>> Case  _base
# ********************************
# ********************************
# Module : 15590000.0 tons
# glass : 14028000.0 tons
# aluminium_frames : 1890000.0 tons
# copper : 12000.0 tons
# silicon : 591000.0 tons
# silver : 5000.0 tons
# Capacity in Year 2030 [GW]: 313.0
# Capacity in Year 2050 [GW]: 698.0
# ****************************
#
# SCENARIO : bifacialTrend
# ~~~~>>>> Case  _base
# ********************************
# ********************************
# Module : 16160000.0 tons
# glass : 14810000.0 tons
# aluminium_frames : 1672000.0 tons
# copper : 12000.0 tons
# silicon : 591000.0 tons
# silver : 5000.0 tons
# Capacity in Year 2030 [GW]: 313.0
# Capacity in Year 2050 [GW]: 698.0
# ****************************
#
# SCENARIO : Irena_EL
# ~~~~>>>> Case  _base
# ********************************
# ********************************
# Module : 11820000.0 tons
# glass : 12040000.0 tons
# aluminium_frames : 1593000.0 tons
# copper : 10000.0 tons
# silicon : 446000.0 tons
# silver : 3000.0 tons
# Capacity in Year 2030 [GW]: 278.0
# Capacity in Year 2050 [GW]: 426.0
# ****************************
#
# SCENARIO : Irena_RL
# ~~~~>>>> Case  _base
# ********************************
# ********************************
# Module : 15768000.0 tons
# glass : 13652000.0 tons
# aluminium_frames : 1886000.0 tons
# copper : 11000.0 tons
# silicon : 525000.0 tons
# silver : 5000.0 tons
# Capacity in Year 2030 [GW]: 312.0
# Capacity in Year 2050 [GW]: 573.0
# ****************************
#
# SCENARIO : PV_ICE
# ~~~~>>>> Case  _high
# ********************************
# ********************************
# Module : 30990000.0 tons
# glass : 27028000.0 tons
# aluminium_frames : 3520000.0 tons
# copper : 24000.0 tons
# silicon : 1247000.0 tons
# silver : 10000.0 tons
# Capacity in Year 2030 [GW]: 609.0
# Capacity in Year 2050 [GW]: 1420.0
# ****************************
#
# SCENARIO : bifacialTrend
# ~~~~>>>> Case  _high
# ********************************
# ********************************
# Module : 32260000.0 tons
# glass : 28910000.0 tons
# aluminium_frames : 3062000.0 tons
# copper : 24000.0 tons
# silicon : 1247000.0 tons
# silver : 10000.0 tons
# Capacity in Year 2030 [GW]: 609.0
# Capacity in Year 2050 [GW]: 1420.0
# ****************************
#
# SCENARIO : Irena_EL
# ~~~~>>>> Case  _high
# ********************************
# ********************************
# Module : 26520000.0 tons
# glass : 24640000.0 tons
# aluminium_frames : 3203000.0 tons
# copper : 20000.0 tons
# silicon : 892000.0 tons
# silver : 7000.0 tons
# Capacity in Year 2030 [GW]: 566.0
# Capacity in Year 2050 [GW]: 670.0
# ****************************
#
# SCENARIO : Irena_RL
# ~~~~>>>> Case  _high
# ********************************
# ********************************
# Module : 30468000.0 tons
# glass : 26252000.0 tons
# aluminium_frames : 3496000.0 tons
# copper : 22000.0 tons
# silicon : 971000.0 tons
# silver : 8000.0 tons
# Capacity in Year 2030 [GW]: 607.0
# Capacity in Year 2050 [GW]: 1120.0
# ****************************

# %%
UScum3sig
# Out:
#       Waste_glass_PV_ICE_base  Waste_silicon_PV_ICE_base  \
# year
# 1996                       62                        123
# 1997                       94                        185
# 1998                      127                        245
# 1999                      174                        328
# 2000                      234                        428
# 2001                      316                        557
# 2002                      446                        748
# 2003                      635                       1010
# 2004                      935                       1420
# 2005                     1910                       1960
# 2006                     2690                       2540
# 2007                     3510                       4270
# 2008                     4320                       5950
# 2009                     5450                       8200
# 2010                     7320                       9970
# 2011                    11700                      14200
# 2012                    19700                      21600
# 2013                    29900                      30500
# 2014                    39400                      38600
# 2015                    53900                      52400
# 2016                    79300                      75000
# 2017                    99000                      88500
# 2018                   117000                      98800
# 2019                   139000                     110000
# 2020                   167000                     122000
# 2021                   187000                     131000
# 2022                   207000                     139000
# 2023                   232000                     149000
# 2024                   257000                     158000
# 2025                   296000                     173000
# 2026                   335000                     188000
# 2027                   379000                     204000
# 2028                   427000                     219000
# 2029                   492000                     241000
# 2030                   572000                     263000
# 2031                   629000                     271000
# 2032                   716000                     280000
# 2033                   801000                     289000
# 2034                   929000                     300000
# 2035                  1090000                     315000
# 2036                  1230000                     329000
# 2037                  1500000                     350000
# 2038                  1700000                     367000
# 2039                  1940000                     390000
# 2040                  2260000                     416000
# 2041                  2550000                     441000
# 2042                  2860000                     467000
# 2043                  3190000                     497000
# 2044                  3520000                     526000
# 2045                  3770000                     550000
# 2046                  4040000                     574000
# 2047                  4310000                     602000
# 2048                  4620000                     632000
# 2049                  4970000                     662000
# 2050                  5370000                     694000
#
#       Waste_silver_PV_ICE_base  Waste_copper_PV_ICE_base  \
# year
# 1996                         0                         0
# 1997                         0                         0
# 1998                         0                         0
# 1999                         0                         0
# 2000                         1                         0
# 2001                         1                         0
# 2002                         1                         0
# 2003                         2                         0
# 2004                         3                         0
# 2005                        12                         0
# 2006                        18                         1
# 2007                        20                         1
# 2008                        22                         1
# 2009                        24                         1
# 2010                        26                         1
# 2011                        31                         2
# 2012                        42                         3
# 2013                        53                         4
# 2014                        66                         6
# 2015                        75                         8
# 2016                        88                        11
# 2017                       103                        15
# 2018                       122                        19
# 2019                       144                        24
# 2020                       171                        31
# 2021                       198                        37
# 2022                       227                        44
# 2023                       258                        52
# 2024                       290                        61
# 2025                       326                        74
# 2026                       364                        88
# 2027                       402                       105
# 2028                       445                       125
# 2029                       497                       153
# 2030                       577                       192
# 2031                       625                       228
# 2032                       706                       285
# 2033                       770                       342
# 2034                       874                       431
# 2035                       990                       544
# 2036                      1070                       645
# 2037                      1230                       840
# 2038                      1330                       990
# 2039                      1450                      1180
# 2040                      1620                      1420
# 2041                      1760                      1660
# 2042                      1900                      1910
# 2043                      2060                      2180
# 2044                      2210                      2460
# 2045                      2310                      2680
# 2046                      2420                      2910
# 2047                      2520                      3140
# 2048                      2630                      3410
# 2049                      2750                      3710
# 2050                      2880                      4060
#
#       Waste_aluminium_frames_PV_ICE_base  Waste_Module_PV_ICE_base  \
# year
# 1996                                   6                       386
# 1997                                   9                       579
# 1998                                  12                       770
# 1999                                  17                      1040
# 2000                                  23                      1370
# 2001                                  33                      1820
# 2002                                  49                      2490
# 2003                                  75                      3440
# 2004                                 116                      4950
# 2005                                 414                      8590
# 2006                                 633                     11800
# 2007                                 696                     17000
# 2008                                 762                     22100
# 2009                                 858                     29100
# 2010                                1020                     36700
# 2011                                1370                     54600
# 2012                                2130                     87000
# 2013                                2920                    127000
# 2014                                3780                    164000
# 2015                                4780                    222000
# 2016                                6470                    322000
# 2017                                8000                    391000
# 2018                                9660                    452000
# 2019                               11700                    520000
# 2020                               14200                    607000
# 2021                               16600                    669000
# 2022                               19100                    731000
# 2023                               22100                    806000
# 2024                               25400                    880000
# 2025                               29800                    998000
# 2026                               34800                   1120000
# 2027                               40600                   1250000
# 2028                               47700                   1390000
# 2029                               57200                   1580000
# 2030                               70300                   1810000
# 2031                               81400                   1960000
# 2032                               99000                   2190000
# 2033                              115000                   2410000
# 2034                              141000                   2740000
# 2035                              172000                   3160000
# 2036                              196000                   3520000
# 2037                              244000                   4200000
# 2038                              276000                   4690000
# 2039                              316000                   5300000
# 2040                              369000                   6100000
# 2041                              415000                   6820000
# 2042                              463000                   7580000
# 2043                              515000                   8410000
# 2044                              565000                   9230000
# 2045                              601000                   9850000
# 2046                              640000                  10500000
# 2047                              677000                  11200000
# 2048                              718000                  12000000
# 2049                              764000                  12800000
# 2050                              818000                  13800000
#
#       Waste_glass_PV_ICE_high  Waste_silicon_PV_ICE_high  \
# year
# 1996                       62                        123
# 1997                       94                        185
# 1998                      127                        245
# 1999                      174                        328
# 2000                      234                        428
# 2001                      316                        557
# 2002                      446                        748
# 2003                      635                       1010
# 2004                      935                       1420
# 2005                     1910                       1960
# 2006                     2690                       2540
# 2007                     3510                       4270
# 2008                     4320                       5950
# 2009                     5450                       8200
# 2010                     7320                       9970
# 2011                    11700                      14200
# 2012                    19700                      21600
# 2013                    29900                      30500
# 2014                    39400                      38600
# 2015                    53900                      52400
# 2016                    79300                      75000
# 2017                    99000                      88500
# 2018                   117000                      98800
# 2019                   139000                     110000
# 2020                   167000                     122000
# 2021                   221000                     149000
# 2022                   272000                     175000
# 2023                   310000                     192000
# 2024                   347000                     207000
# 2025                   436000                     250000
# 2026                   523000                     291000
# 2027                   593000                     322000
# 2028                   668000                     351000
# 2029                   765000                     392000
# 2030                   875000                     431000
# 2031                   976000                     464000
# 2032                  1100000                     498000
# 2033                  1230000                     529000
# 2034                  1400000                     562000
# 2035                  1600000                     600000
# 2036                  1780000                     637000
# 2037                  2100000                     685000
# 2038                  2350000                     729000
# 2039                  2650000                     779000
# 2040                  3030000                     833000
# 2041                  3340000                     859000
# 2042                  3680000                     886000
# 2043                  4070000                     913000
# 2044                  4470000                     941000
# 2045                  4840000                     969000
# 2046                  5270000                     999000
# 2047                  5760000                    1030000
# 2048                  6370000                    1070000
# 2049                  7110000                    1120000
# 2050                  7990000                    1180000
#
#       Waste_silver_PV_ICE_high  Waste_copper_PV_ICE_high  ...  \
# year                                                      ...
# 1996                         0                         0  ...
# 1997                         0                         0  ...
# 1998                         0                         0  ...
# 1999                         0                         0  ...
# 2000                         1                         0  ...
# 2001                         1                         0  ...
# 2002                         1                         0  ...
# 2003                         2                         0  ...
# 2004                         3                         0  ...
# 2005                        12                         0  ...
# 2006                        18                         1  ...
# 2007                        20                         1  ...
# 2008                        22                         1  ...
# 2009                        24                         1  ...
# 2010                        26                         1  ...
# 2011                        31                         2  ...
# 2012                        42                         3  ...
# 2013                        53                         4  ...
# 2014                        66                         6  ...
# 2015                        75                         8  ...
# 2016                        88                        11  ...
# 2017                       103                        15  ...
# 2018                       122                        19  ...
# 2019                       144                        24  ...
# 2020                       171                        31  ...
# 2021                       206                        42  ...
# 2022                       243                        54  ...
# 2023                       277                        64  ...
# 2024                       312                        75  ...
# 2025                       359                        97  ...
# 2026                       408                       121  ...
# 2027                       453                       143  ...
# 2028                       502                       168  ...
# 2029                       561                       202  ...
# 2030                       648                       247  ...
# 2031                       705                       292  ...
# 2032                       795                       357  ...
# 2033                       867                       422  ...
# 2034                       981                       519  ...
# 2035                      1110                       640  ...
# 2036                      1190                       751  ...
# 2037                      1360                       958  ...
# 2038                      1480                      1120  ...
# 2039                      1610                      1330  ...
# 2040                      1790                      1600  ...
# 2041                      1940                      1850  ...
# 2042                      2100                      2140  ...
# 2043                      2270                      2460  ...
# 2044                      2450                      2810  ...
# 2045                      2590                      3140  ...
# 2046                      2760                      3530  ...
# 2047                      2930                      3970  ...
# 2048                      3130                      4510  ...
# 2049                      3380                      5170  ...
# 2050                      3670                      5960  ...
#
#       VirginStock_aluminium_frames_Irena_RL_high  \
# year
# 1996                                         539
# 1997                                         782
# 1998                                        1010
# 1999                                        1330
# 2000                                        1710
# 2001                                        2200
# 2002                                        2930
# 2003                                        3930
# 2004                                        5460
# 2005                                        6900
# 2006                                        8340
# 2007                                       13000
# 2008                                       17400
# 2009                                       23300
# 2010                                       33100
# 2011                                       56300
# 2012                                       95300
# 2013                                      136000
# 2014                                      173000
# 2015                                      233000
# 2016                                      337000
# 2017                                      413000
# 2018                                      482000
# 2019                                      559000
# 2020                                      662000
# 2021                                      874000
# 2022                                     1080000
# 2023                                     1220000
# 2024                                     1350000
# 2025                                     1750000
# 2026                                     2140000
# 2027                                     2440000
# 2028                                     2740000
# 2029                                     3140000
# 2030                                     3550000
# 2031                                     3870000
# 2032                                     4190000
# 2033                                     4480000
# 2034                                     4770000
# 2035                                     5090000
# 2036                                     5400000
# 2037                                     5780000
# 2038                                     6150000
# 2039                                     6550000
# 2040                                     6960000
# 2041                                     7080000
# 2042                                     7200000
# 2043                                     7310000
# 2044                                     7410000
# 2045                                     7540000
# 2046                                     7670000
# 2047                                     7830000
# 2048                                     7980000
# 2049                                     8210000
# 2050                                     8430000
#
#       VirginStock_Module_Irena_RL_high  Capacity_PV_ICE_base  \
# year
# 1996                              2110              22200000
# 1997                              3160              33800000
# 1998                              4190              45500000
# 1999                              5640              62200000
# 2000                              7390              82800000
# 2001                              9690             110000000
# 2002                             13100             152000000
# 2003                             17900             211000000
# 2004                             25400             304000000
# 2005                             32700             388000000
# 2006                             40100             477000000
# 2007                             63900             800000000
# 2008                             86700            1110000000
# 2009                            118000            1540000000
# 2010                            169000            2250000000
# 2011                            291000            4030000000
# 2012                            500000            7070000000
# 2013                            757000           11100000000
# 2014                            993000           14800000000
# 2015                           1400000           21600000000
# 2016                           2140000           34400000000
# 2017                           2700000           44100000000
# 2018                           3210000           53300000000
# 2019                           3800000           64000000000
# 2020                           4620000           78700000000
# 2021                           6410000           88800000000
# 2022                           8150000           98800000000
# 2023                           9360000          112000000000
# 2024                          10500000          125000000000
# 2025                          14100000          151000000000
# 2026                          17600000          177000000000
# 2027                          20400000          204000000000
# 2028                          23100000          232000000000
# 2029                          27100000          273000000000
# 2030                          31100000          313000000000
# 2031                          34300000          323000000000
# 2032                          37600000          332000000000
# 2033                          40500000          340000000000
# 2034                          43500000          347000000000
# 2035                          46700000          359000000000
# 2036                          49900000          371000000000
# 2037                          53700000          382000000000
# 2038                          57500000          394000000000
# 2039                          61700000          413000000000
# 2040                          65800000          430000000000
# 2041                          67100000          450000000000
# 2042                          68300000          470000000000
# 2043                          69400000          495000000000
# 2044                          70500000          521000000000
# 2045                          71900000          545000000000
# 2046                          73300000          568000000000
# 2047                          74900000          603000000000
# 2048                          76500000          637000000000
# 2049                          78900000          668000000000
# 2050                          81200000          698000000000
#
#       Capacity_PV_ICE_high  Capacity_bifacialTrend_base  \
# year
# 1996              22200000                     22200000
# 1997              33800000                     33800000
# 1998              45500000                     45500000
# 1999              62200000                     62200000
# 2000              82800000                     82800000
# 2001             110000000                    110000000
# 2002             152000000                    152000000
# 2003             211000000                    211000000
# 2004             304000000                    304000000
# 2005             388000000                    388000000
# 2006             477000000                    477000000
# 2007             800000000                    800000000
# 2008            1110000000                   1110000000
# 2009            1540000000                   1540000000
# 2010            2250000000                   2250000000
# 2011            4030000000                   4030000000
# 2012            7070000000                   7070000000
# 2013           11100000000                  11100000000
# 2014           14800000000                  14800000000
# 2015           21600000000                  21600000000
# 2016           34400000000                  34400000000
# 2017           44100000000                  44100000000
# 2018           53300000000                  53300000000
# 2019           64000000000                  64000000000
# 2020           78700000000                  78700000000
# 2021          113000000000                  88800000000
# 2022          147000000000                  98800000000
# 2023          170000000000                 112000000000
# 2024          194000000000                 125000000000
# 2025          267000000000                 151000000000
# 2026          340000000000                 177000000000
# 2027          396000000000                 204000000000
# 2028          452000000000                 232000000000
# 2029          530000000000                 273000000000
# 2030          609000000000                 313000000000
# 2031          671000000000                 323000000000
# 2032          733000000000                 332000000000
# 2033          788000000000                 340000000000
# 2034          842000000000                 347000000000
# 2035          902000000000                 359000000000
# 2036          963000000000                 371000000000
# 2037         1030000000000                 382000000000
# 2038         1100000000000                 394000000000
# 2039         1180000000000                 413000000000
# 2040         1260000000000                 430000000000
# 2041         1270000000000                 450000000000
# 2042         1280000000000                 470000000000
# 2043         1290000000000                 495000000000
# 2044         1300000000000                 521000000000
# 2045         1320000000000                 545000000000
# 2046         1330000000000                 568000000000
# 2047         1350000000000                 603000000000
# 2048         1370000000000                 637000000000
# 2049         1400000000000                 668000000000
# 2050         1420000000000                 698000000000
#
#       Capacity_bifacialTrend_high  Capacity_Irena_EL_base  \
# year
# 1996                     22200000                22200000
# 1997                     33800000                33800000
# 1998                     45500000                45400000
# 1999                     62200000                62000000
# 2000                     82800000                82500000
# 2001                    110000000               110000000
# 2002                    152000000               151000000
# 2003                    211000000               209000000
# 2004                    304000000               301000000
# 2005                    388000000               394000000
# 2006                    477000000               487000000
# 2007                    800000000               805000000
# 2008                   1110000000              1110000000
# 2009                   1540000000              1530000000
# 2010                   2250000000              2230000000
# 2011                   4030000000              3990000000
# 2012                   7070000000              7020000000
# 2013                  11100000000             11000000000
# 2014                  14800000000             14600000000
# 2015                  21600000000             21400000000
# 2016                  34400000000             34100000000
# 2017                  44100000000             43600000000
# 2018                  53300000000             52500000000
# 2019                  64000000000             62900000000
# 2020                  78700000000             77000000000
# 2021                 113000000000             86100000000
# 2022                 147000000000             94900000000
# 2023                 170000000000            107000000000
# 2024                 194000000000            118000000000
# 2025                 267000000000            141000000000
# 2026                 340000000000            163000000000
# 2027                 396000000000            186000000000
# 2028                 452000000000            209000000000
# 2029                 530000000000            244000000000
# 2030                 609000000000            278000000000
# 2031                 671000000000            281000000000
# 2032                 733000000000            282000000000
# 2033                 788000000000            281000000000
# 2034                 842000000000            279000000000
# 2035                 902000000000            281000000000
# 2036                 963000000000            281000000000
# 2037                1030000000000            281000000000
# 2038                1100000000000            280000000000
# 2039                1180000000000            286000000000
# 2040                1260000000000            291000000000
# 2041                1270000000000            297000000000
# 2042                1280000000000            302000000000
# 2043                1290000000000            315000000000
# 2044                1300000000000            327000000000
# 2045                1320000000000            336000000000
# 2046                1330000000000            345000000000
# 2047                1350000000000            366000000000
# 2048                1370000000000            388000000000
# 2049                1400000000000            407000000000
# 2050                1420000000000            426000000000
#
#       Capacity_Irena_EL_high  Capacity_Irena_RL_base  Capacity_Irena_RL_high
# year
# 1996                22200000                22200000                22200000
# 1997                33800000                33800000                33800000
# 1998                45400000                45500000                45500000
# 1999                62000000                62200000                62200000
# 2000                82500000                82900000                82900000
# 2001               110000000               111000000               111000000
# 2002               151000000               153000000               153000000
# 2003               209000000               212000000               212000000
# 2004               301000000               306000000               306000000
# 2005               394000000               401000000               401000000
# 2006               487000000               498000000               498000000
# 2007               805000000               821000000               821000000
# 2008              1110000000              1130000000              1130000000
# 2009              1530000000              1560000000              1560000000
# 2010              2230000000              2270000000              2270000000
# 2011              3990000000              4050000000              4050000000
# 2012              7020000000              7110000000              7110000000
# 2013             11000000000             11100000000             11100000000
# 2014             14600000000             14800000000             14800000000
# 2015             21400000000             21600000000             21600000000
# 2016             34100000000             34500000000             34500000000
# 2017             43600000000             44200000000             44200000000
# 2018             52500000000             53400000000             53400000000
# 2019             62900000000             64200000000             64200000000
# 2020             77000000000             78900000000             78900000000
# 2021            110000000000             89000000000            113000000000
# 2022            143000000000             99100000000            147000000000
# 2023            165000000000            112000000000            171000000000
# 2024            186000000000            126000000000            194000000000
# 2025            256000000000            151000000000            268000000000
# 2026            326000000000            177000000000            340000000000
# 2027            377000000000            204000000000            396000000000
# 2028            426000000000            231000000000            451000000000
# 2029            497000000000            272000000000            530000000000
# 2030            566000000000            312000000000            607000000000
# 2031            616000000000            321000000000            669000000000
# 2032            664000000000            329000000000            729000000000
# 2033            702000000000            335000000000            783000000000
# 2034            737000000000            341000000000            835000000000
# 2035            774000000000            351000000000            892000000000
# 2036            808000000000            361000000000            948000000000
# 2037            848000000000            370000000000           1010000000000
# 2038            885000000000            377000000000           1080000000000
# 2039            926000000000            392000000000           1150000000000
# 2040            962000000000            406000000000           1210000000000
# 2041            934000000000            421000000000           1210000000000
# 2042            902000000000            434000000000           1210000000000
# 2043            865000000000            453000000000           1200000000000
# 2044            826000000000            471000000000           1190000000000
# 2045            792000000000            484000000000           1180000000000
# 2046            757000000000            495000000000           1160000000000
# 2047            726000000000            517000000000           1150000000000
# 2048            696000000000            538000000000           1130000000000
# 2049            683000000000            556000000000           1130000000000
# 2050            670000000000            573000000000           1120000000000
#
# [55 rows x 152 columns]

# %%
print(" WASTE EoL CUMULATIVE RESULTS [Tonnes] ")
print(" ******************************************")
filter_col = [col for col in UScum3sig if (col.startswith('Waste_EOL_Module')) ]
display(UScum3sig[filter_col].loc[[2016,2020,2030, 2040, 2050]])
# Out:
#  WASTE EoL CUMULATIVE RESULTS [Tonnes]
#  ******************************************
#       Waste_EOL_Module_PV_ICE_base  Waste_EOL_Module_PV_ICE_high  \
# year
# 2016                        493000                        493000
# 2020                        939000                        939000
# 2030                       2960000                       4440000
# 2040                      11300000                      15100000
# 2050                      26200000                      38700000
#
#       Waste_EOL_Module_bifacialTrend_base  \
# year
# 2016                               493000
# 2020                               939000
# 2030                              3010000
# 2040                             11400000
# 2050                             26500000
#
#       Waste_EOL_Module_bifacialTrend_high  Waste_EOL_Module_Irena_EL_base  \
# year
# 2016                               493000                          130000
# 2020                               939000                          583000
# 2030                              4540000                         9150000
# 2040                             15300000                        38400000
# 2050                             39400000                        79300000
#
#       Waste_EOL_Module_Irena_EL_high  Waste_EOL_Module_Irena_RL_base  \
# year
# 2016                          130000                            9850
# 2020                          583000                           39900
# 2030                        10900000                         1260000
# 2040                        70000000                        14100000
# 2050                       189000000                        49100000
#
#       Waste_EOL_Module_Irena_RL_high
# year
# 2016                            9850
# 2020                           39900
# 2030                         1290000
# 2040                        18200000
# 2050                        96600000

# %%
UScum['Waste_EOL_Module_PV_ICE_base'].iloc[-1]
# Out:
# 26249427.314932633

# %%
print(" WASTE EoL CUMULATIVE RESULTS [Tonnes] ")
print(" ******************************************")
filter_col = [col for col in UScum if (col.startswith('Waste_EOL_Module')) ]
display(UScum[filter_col].loc[[2016,2020,2030, 2040, 2050]])
# Out:
#  WASTE EoL CUMULATIVE RESULTS [Tonnes]
#  ******************************************
#       Waste_EOL_Module_PV_ICE_base  Waste_EOL_Module_PV_ICE_high  \
# year
# 2016                  4.931018e+05                  4.931018e+05
# 2020                  9.391024e+05                  9.391024e+05
# 2030                  2.964938e+06                  4.441818e+06
# 2040                  1.133208e+07                  1.510954e+07
# 2050                  2.624943e+07                  3.872649e+07
#
#       Waste_EOL_Module_bifacialTrend_base  \
# year
# 2016                         4.931018e+05
# 2020                         9.390218e+05
# 2030                         3.010768e+06
# 2040                         1.139637e+07
# 2050                         2.651854e+07
#
#       Waste_EOL_Module_bifacialTrend_high  Waste_EOL_Module_Irena_EL_base  \
# year
# 2016                         4.931018e+05                    1.296684e+05
# 2020                         9.390218e+05                    5.828125e+05
# 2030                         4.544279e+06                    9.153169e+06
# 2040                         1.528954e+07                    3.837116e+07
# 2050                         3.938830e+07                    7.925167e+07
#
#       Waste_EOL_Module_Irena_EL_high  Waste_EOL_Module_Irena_RL_base  \
# year
# 2016                    1.296684e+05                    9.852739e+03
# 2020                    5.828125e+05                    3.987065e+04
# 2030                    1.087429e+07                    1.263829e+06
# 2040                    7.000096e+07                    1.408877e+07
# 2050                    1.886523e+08                    4.907744e+07
#
#       Waste_EOL_Module_Irena_RL_high
# year
# 2016                    9.852739e+03
# 2020                    3.987065e+04
# 2030                    1.288576e+06
# 2040                    1.817403e+07
# 2050                    9.657505e+07

# %% [markdown]
# ### Bonus: Bifacial Trend Cumulative Virgin Needs (not plotted, just values)

# %%
name2 = 'bifacialTrend_high'
name0 = 'bifacialTrend_base'

cumulations2050 = {}
for ii in range(0, len(materials)):
    matcum = []
    matcum.append(UScum[keyw+materials[ii]+'_'+name0].loc[2050])
    matcum.append(UScum[keyw+materials[ii]+'_'+name2].loc[2050])
    cumulations2050[materials[ii]] = matcum

dfcumulations2050 = pd.DataFrame.from_dict(cumulations2050) 
dfcumulations2050 = dfcumulations2050/1000000   # in Million Tonnes
 
print("Cumulative Virgin Needs by 2050 Million Tones by Scenario for Bifacial Trend")
dfcumulations2050[['glass','silicon','silver','copper','aluminium_frames']].sum(axis=1)
# Out:
# Cumulative Virgin Needs by 2050 Million Tones by Scenario for Bifacial Trend
# 0    1.335633
# 1    2.550716
# dtype: float64

# %%
name2 = 'Irena_EL_high'
name0 = 'Irena_EL_base'

cumulations2050 = {}
for ii in range(0, len(materials)):
    matcum = []
    matcum.append(UScum[keyw+materials[ii]+'_'+name0].loc[2050])
    matcum.append(UScum[keyw+materials[ii]+'_'+name2].loc[2050])
    cumulations2050[materials[ii]] = matcum

dfcumulations2050 = pd.DataFrame.from_dict(cumulations2050) 
dfcumulations2050 = dfcumulations2050/1000000   # in Million Tonnes
 
print("Cumulative Virgin Needs by 2050 Million Tones by Scenario for Irena_EL")
dfcumulations2050[['glass','silicon','silver','copper','aluminium_frames']].sum(axis=1)
# Out:
# Cumulative Virgin Needs by 2050 Million Tones by Scenario for Irena_EL
# 0    6.068603e-17
# 1   -1.169656e-16
# dtype: float64

# %%
name2 = 'Irena_RL_high'
name0 = 'Irena_RL_base'

cumulations2050 = {}
for ii in range(0, len(materials)):
    matcum = []
    matcum.append(UScum[keyw+materials[ii]+'_'+name0].loc[2050])
    matcum.append(UScum[keyw+materials[ii]+'_'+name2].loc[2050])
    cumulations2050[materials[ii]] = matcum

dfcumulations2050 = pd.DataFrame.from_dict(cumulations2050) 
dfcumulations2050 = dfcumulations2050/1000000   # in Million Tonnes
 
print("Cumulative Virgin Needs by 2050 Million Tones by Scenario for Irena_RL")
dfcumulations2050[['glass','silicon','silver','copper','aluminium_frames']].sum(axis=1)
# Out:
# Cumulative Virgin Needs by 2050 Million Tones by Scenario for Irena_RL
# 0    6.068603e-17
# 1   -1.169656e-16
# dtype: float64

# %% [markdown]
# ### Waste by year

# %%
plt.rcParams.update({'font.size': 15})
plt.rcParams['figure.figsize'] = (15, 8)
keyw='Waste_'
materials = ['glass', 'silicon', 'silver', 'copper', 'aluminium_frames']


f, (a0, a1) = plt.subplots(1, 2, gridspec_kw={'width_ratios': [3, 1]})

########################    
# SUBPLOT 1
########################
#######################
   
# loop plotting over scenarios
name2 = 'PV_ICE_high'
name0 = 'PV_ICE_base'


# SCENARIO 1 ***************
modulemat = (USyearly[keyw+materials[0]+'_'+name0]+USyearly[keyw+materials[1]+'_'+name0]+
            USyearly[keyw+materials[2]+'_'+name0]+USyearly[keyw+materials[3]+'_'+name0]+
            USyearly[keyw+materials[4]+'_'+name0])
glassmat = (USyearly[keyw+materials[0]+'_'+name0])
modulemat = modulemat/1000000
glassmat = glassmat/1000000 
a0.plot(USyearly.index, modulemat, 'k.', linewidth=5, label='S1: '+name0+' module mass')
a0.plot(USyearly.index, glassmat, 'k', linewidth=5, label='S1: '+name0+' glass mass only')
a0.fill_between(USyearly.index, glassmat, modulemat, color='k', alpha=0.3,
                 interpolate=True)

# SCENARIO 2 ***************
modulemat = (USyearly[keyw+materials[0]+'_'+name2]+USyearly[keyw+materials[1]+'_'+name2]+
            USyearly[keyw+materials[2]+'_'+name2]+USyearly[keyw+materials[3]+'_'+name2]+
            USyearly[keyw+materials[4]+'_'+name2])
glassmat = (USyearly[keyw+materials[0]+'_'+name2])
modulemat = modulemat/1000000
glassmat = glassmat/1000000 
a0.plot(USyearly.index, modulemat, 'c.', linewidth=5, label='S2: '+name2+' module mass')
a0.plot(USyearly.index, glassmat, 'c', linewidth=5, label='S2: '+name2+' glass mass only')
a0.fill_between(USyearly.index, glassmat, modulemat, color='c', alpha=0.3,
                 interpolate=True)

a0.legend()
a0.set_title('Yearly Material Waste by Scenario')
a0.set_ylabel('Mass [Million Tonnes]')
a0.set_xlim([2020, 2050])
a0.set_xlabel('Years')
    
    
########################    
# SUBPLOT 2
########################
#######################
# Calculate    

cumulations2050 = {}
for ii in range(0, len(materials)):
    matcum = []
    matcum.append(UScum[keyw+materials[ii]+'_'+name0].loc[2050])
    matcum.append(UScum[keyw+materials[ii]+'_'+name2].loc[2050])
    cumulations2050[materials[ii]] = matcum

dfcumulations2050 = pd.DataFrame.from_dict(cumulations2050) 
dfcumulations2050 = dfcumulations2050/1000000   # in Million Tonnes

dfcumulations2050['bottom1'] = dfcumulations2050['glass']
dfcumulations2050['bottom2'] = dfcumulations2050['bottom1']+dfcumulations2050['aluminium_frames']
dfcumulations2050['bottom3'] = dfcumulations2050['bottom2']+dfcumulations2050['silicon']
dfcumulations2050['bottom4'] = dfcumulations2050['bottom3']+dfcumulations2050['copper']


## Plot BARS Stuff
ind=np.arange(2)
width=0.35 # width of the bars.
p0 = a1.bar(ind, dfcumulations2050['glass'], width, color='c')
p1 = a1.bar(ind, dfcumulations2050['aluminium_frames'], width,
             bottom=dfcumulations2050['bottom1'])
p2 = a1.bar(ind, dfcumulations2050['silicon'], width,
             bottom=dfcumulations2050['bottom2'])
p3 = a1.bar(ind, dfcumulations2050['copper'], width,
             bottom=dfcumulations2050['bottom3'])
p4 = a1.bar(ind, dfcumulations2050['silver'], width,
             bottom=dfcumulations2050['bottom4'])

a1.yaxis.set_label_position("right")
a1.yaxis.tick_right()
a1.set_ylabel('Cumulative Waste by 2050 [Million Tonnes]')
a1.set_xlabel('Scenario')
a1.set_xticks(ind, ('S1', 'S2'))
#plt.yticks(np.arange(0, 81, 10))
a1.legend((p0[0], p1[0], p2[0], p3[0], p4[0] ), ('Glass', 'aluminium_frames', 'Silicon','Copper','Silver'))

f.tight_layout()

f.savefig(' Fig_2x1_Yearly WASTE by Scenario and Cumulatives_NREL2018.png', dpi=600)

print("Cumulative Waste by 2050 Million Tones by case")
dfcumulations2050[['glass','silicon','silver','copper','aluminium_frames']].sum(axis=1)
# Out:
# Cumulative Waste by 2050 Million Tones by case
# 0     6.888243
# 1    10.302106
# dtype: float64

# %%
plt.rcParams.update({'font.size': 15})
plt.rcParams['figure.figsize'] = (15, 8)
keyw='Waste_EOL_'
materials = ['glass', 'silicon', 'silver', 'copper', 'aluminium_frames']


f, (a0, a1) = plt.subplots(1, 2, gridspec_kw={'width_ratios': [3, 1]})

########################    
# SUBPLOT 1
########################
#######################
   
# loop plotting over scenarios
name2 = 'PV_ICE_high'
name0 = 'PV_ICE_base'


# SCENARIO 1 ***************
modulemat = (USyearly[keyw+materials[0]+'_'+name0]+USyearly[keyw+materials[1]+'_'+name0]+
            USyearly[keyw+materials[2]+'_'+name0]+USyearly[keyw+materials[3]+'_'+name0]+
            USyearly[keyw+materials[4]+'_'+name0])
glassmat = (USyearly[keyw+materials[0]+'_'+name0])
modulemat = modulemat/1000000
glassmat = glassmat/1000000 
a0.plot(USyearly.index, modulemat, 'k.', linewidth=5, label='S1: '+name0+' module mass')
a0.plot(USyearly.index, glassmat, 'k', linewidth=5, label='S1: '+name0+' glass mass only')
a0.fill_between(USyearly.index, glassmat, modulemat, color='k', alpha=0.3,
                 interpolate=True)

# SCENARIO 2 ***************
modulemat = (USyearly[keyw+materials[0]+'_'+name2]+USyearly[keyw+materials[1]+'_'+name2]+
            USyearly[keyw+materials[2]+'_'+name2]+USyearly[keyw+materials[3]+'_'+name2]+
            USyearly[keyw+materials[4]+'_'+name2])
glassmat = (USyearly[keyw+materials[0]+'_'+name2])
modulemat = modulemat/1000000
glassmat = glassmat/1000000 
a0.plot(USyearly.index, modulemat, 'c.', linewidth=5, label='S2: '+name2+' module mass')
a0.plot(USyearly.index, glassmat, 'c', linewidth=5, label='S2: '+name2+' glass mass only')
a0.fill_between(USyearly.index, glassmat, modulemat, color='c', alpha=0.3,
                 interpolate=True)

a0.legend()
a0.set_title('Yearly Material Waste by Scenario')
a0.set_ylabel('Mass [Million Tonnes]')
a0.set_xlim([2020, 2050])
a0.set_xlabel('Years')
    
    
########################    
# SUBPLOT 2
########################
#######################
# Calculate    

cumulations2050 = {}
for ii in range(0, len(materials)):
    matcum = []
    matcum.append(UScum[keyw+materials[ii]+'_'+name0].loc[2050])
    matcum.append(UScum[keyw+materials[ii]+'_'+name2].loc[2050])
    cumulations2050[materials[ii]] = matcum

dfcumulations2050 = pd.DataFrame.from_dict(cumulations2050) 
dfcumulations2050 = dfcumulations2050/1000000   # in Million Tonnes

dfcumulations2050['bottom1'] = dfcumulations2050['glass']
dfcumulations2050['bottom2'] = dfcumulations2050['bottom1']+dfcumulations2050['aluminium_frames']
dfcumulations2050['bottom3'] = dfcumulations2050['bottom2']+dfcumulations2050['silicon']
dfcumulations2050['bottom4'] = dfcumulations2050['bottom3']+dfcumulations2050['copper']


## Plot BARS Stuff
ind=np.arange(2)
width=0.35 # width of the bars.
p0 = a1.bar(ind, dfcumulations2050['glass'], width, color='c')
p1 = a1.bar(ind, dfcumulations2050['aluminium_frames'], width,
             bottom=dfcumulations2050['bottom1'])
p2 = a1.bar(ind, dfcumulations2050['silicon'], width,
             bottom=dfcumulations2050['bottom2'])
p3 = a1.bar(ind, dfcumulations2050['copper'], width,
             bottom=dfcumulations2050['bottom3'])
p4 = a1.bar(ind, dfcumulations2050['silver'], width,
             bottom=dfcumulations2050['bottom4'])

a1.yaxis.set_label_position("right")
a1.yaxis.tick_right()
a1.set_ylabel('Cumulative EOL Only Waste by 2050 [Million Tonnes]')
a1.set_xlabel('Scenario')
a1.set_xticks(ind, ('S1', 'S2'))
#plt.yticks(np.arange(0, 81, 10))
a1.legend((p0[0], p1[0], p2[0], p3[0], p4[0] ), ('Glass', 'aluminium_frames', 'Silicon','Copper','Silver'))

f.tight_layout()

f.savefig('Fig_2x1_Yearly EOL Only WASTE by Scenario and Cumulatives_NREL2018.png', dpi=600)

print("Cumulative Eol Only Waste by 2050 Million Tones by case")
dfcumulations2050[['glass','silicon','silver','copper','aluminium_frames']].sum(axis=1)
# Out:
# Cumulative Eol Only Waste by 2050 Million Tones by case
# 0    5.584698
# 1    7.820177
# dtype: float64
